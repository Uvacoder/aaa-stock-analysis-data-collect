# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import pandas as pd
import os
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn import metrics
from math import sqrt
from sklearn.neighbors import DistanceMetric
from sklearn.model_selection import GridSearchCV
import prettytable
from prettytable import PrettyTable

import statsmodels.api as sm

import warnings; warnings.simplefilter('ignore')

# %%
path = os.getcwd()
path
# Out:
# 'C:\\Users\\venu\\Desktop\\Stock Market Analysis'

# %% [markdown]
# # Pre-process the data

# %%
def pre_process_data(data,null_threshold):
    """
    Drops Date and Unix Date columns from the data.
    Drops the columns which has null values more than specified null_threshold.
    Replaces infinite values with NAN.
    Drops the rows which has null values.

    Parameters
    ----------
    data : dataframe

    null_threshold : numeric
        numeric value describing the amount of null values that can be present.

    Returns
    -------
    data : dataframe
        an updated dataframe after performing all the opertaions.
    """
    
    data.drop(columns=['Unix Date','Date'],axis=1,inplace=True)
    total = data.shape[0]
    for col in data.columns:
        if null_threshold * total / 100 < data[col].isnull().sum():
            data.drop(columns=[col],axis=1,inplace=True)
    data.replace([np.inf, -np.inf], np.nan, inplace=True)
    data = data.apply(pd.to_numeric,errors='coerce')
    data.dropna(axis=0,inplace=True)
    return data

# %% [markdown]
# # Removing columns based on the dependent column

# %%
def dependent_column(data,column):
    """
    Removes all the Next Day columns.
    Removes all the non Growth Rate Columns (GR)
    add the predictor column to list of columns.

    Parameters
    ----------
    data : dataframe

    column : string
        name of the predictor column 

    Returns
    -------
    data : dataframe
        an updated dataframe after performing all the opertaions.
    column : string
        name of the predictor column
    """
    cols = [col for col in data.columns if "next" not in col.lower() and col.lower().endswith("gr")]
    cols.append(column)
    data = data[cols]
    return (data,column)

# %% [markdown]
# # Feature Selection Methods

# %%
def forward_selection(data, target, significance_level=0.05):
    initial_features = data.columns.tolist()
    best_features = []
    while (len(initial_features)>0):
        remaining_features = list(set(initial_features)-set(best_features))
        new_pval = pd.Series(index=remaining_features)
        for new_column in remaining_features:
            model = sm.OLS(target, sm.add_constant(data[best_features+[new_column]]).astype(float)).fit()
            new_pval[new_column] = model.pvalues[new_column]
        min_p_value = new_pval.min()
        if(min_p_value<significance_level):
            best_features.append(new_pval.idxmin())
        else:
            break
    return best_features

# %%
def backward_elimination(data, target,significance_level = 0.05):
    features = data.columns.tolist()
    while(len(features)>0):
        features_with_constant = sm.add_constant(data[features]).astype(float)
        p_values = sm.OLS(target, features_with_constant).fit().pvalues[1:]
        max_p_value = p_values.max()
        if(max_p_value >= significance_level):
            excluded_feature = p_values.idxmax()
            features.remove(excluded_feature)
        else:
            break 
    return features

# %% [markdown]
# # KNN Model

# %%
def best_parameters(X,Y):
    params = {'n_neighbors':np.arange(1,105,5), 'weights':['uniform', 'distance'], 'metric':['euclidean', 'manhattan']}
    knn = KNeighborsRegressor()    
    model = GridSearchCV(knn, params)
    model.fit(X,Y)
    k = model.best_params_['n_neighbors']
    params = {'n_neighbors':np.arange(k-5, k+5), 'weights':['uniform', 'distance'], 'metric':['euclidean', 'manhattan']}
    knn = KNeighborsRegressor()
    model = GridSearchCV(knn, params)
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=0)
    model.fit(X_train,y_train)
    return model.best_params_

# %%
def k_nearest_neighbours(X,Y, method, value, name):
    params = best_parameters(X,Y)
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=0)
    knn = KNeighborsRegressor(**params)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    
    rmse = sqrt(metrics.mean_squared_error(y_test, y_pred))
    mae = metrics.mean_absolute_error(y_test, y_pred)
    mse = metrics.mean_squared_error(y_test, y_pred)
    r2 = metrics.r2_score(y_test, y_pred)
    
    pred_actual = pd.DataFrame(list(zip(y_pred, y_test)), 
                   columns =['Predicted Values', 'Actual Values'])
    pred_actual.to_csv("C:\\Users\\venu\\Desktop\\Stock Market Analysis\\Data\\Models_Results\\" + name[2:8] + "_KNN_Regression_" + "FI_" + method + "_sd_all_" + str(value) + ".csv" , index = False)
    
    c = 0
    for a,b in zip(y_test, y_pred):
#         if (float(a) * float(b) >= 0):
#             c += 1
        if (a > 0 and b > 0) or (a < 0 and b < 0):
#             print(a, b)
            c += 1
    
    print(c, len(y_test), len(y_train) + len(y_test))
    direction = c / len(y_test)
    
    myres =  {"RMSE":rmse,"MAE":mae,"MSE":mse,"rsquared_adj":r2}
    myres.update(params)
    myres.update({"Percentage":direction})
    
    return myres

# %% [markdown]
# # Finding results from each set of important features

# %%
def fit_KNN(df, column, method, value, name, results):
    print("KNN Model fitted using columns obtained from feature importance using " + method + " : ")
    X = df[df.columns[:-1]]
    Y = df[column].values
    
    model_result = k_nearest_neighbours(X,Y, method, value, name)
    
    print("Percentage of correct direction : ", model_result["Percentage"])
    
    results["KNN_Regression_FI_" + method + "_" + str(value)] = model_result["Percentage"]
    
    create_pretty_table(name , "KNN_Regression", method + " " + value, model_result)

# %%
def get_results_from_FI_ForwardSelection(df1, name, column, results):
    print("Features Importance using Forward Selection Method")
    print("*****************************************************************************************")
    method = "ForwardSelection"
    X = df1[df1.columns[:-1]]
    Y = df1[column].values
    forward_features = forward_selection(X,Y)
    print("Features obtained from Forward Selection method : ") 
    print("--------------------------------------")
    print(forward_features)
    if (len(forward_features) != 0):
        forward_features.append(column)
        df_fs = df1[forward_features]
        fit_KNN(df_fs, column, method, '', name, results)
    print("*****************************************************************************************")

# %%
def get_results_from_FI_BackwardElimination(df1, name, column, results):
    print("Features Importance using Backward Elimination Method")
    print("*****************************************************************************************")
    method = "BackwardElimination"
    X = df1[df1.columns[:-1]]
    Y = df1[column].values
    backward_features = backward_elimination(X,Y)
    print("Features obtained from Backward Elimination method : ") 
    print("--------------------------------------")
    print(backward_features)
    if (len(backward_features) != 0):
        backward_features.append(column)
        df_be = df1[backward_features]
        fit_KNN(df_be, column, method, '', name, results)
    print("*****************************************************************************************")

# %%
def get_results_from_FI_AllFeatures(df1, name, column, results):
    print("All Features are considered : ")
    print("*****************************************************************************************")
    method = "AllFeaturesConsideration"
    X = df1[df1.columns[:-1]]
    Y = df1[column].values
    all_features = list(X.columns)
    print("All Features are --->>") 
    print("--------------------------------------")
    print(all_features)
    if (len(all_features) != 0):
        all_features.append(column)
        df_all = df1[all_features]
        fit_KNN(df_all, column, method, '', name, results)
    print("*****************************************************************************************")

# %%
def get_results_from_each_set(data, name, final_df):
    df = pre_process_data(data, 60)
    column = "Next Day Close Price GR"
    (df1, column) = dependent_column(df, column)
    results = {}
    get_results_from_FI_ForwardSelection(df1, name, column, results)
    get_results_from_FI_BackwardElimination(df1, name, column, results)
    get_results_from_FI_AllFeatures(df1, name, column, results)
    sorted_results = sorted(results.items(), key=lambda item: item[1])
    max_row = {'Company' : name[2 : 8] + "-" + companies[name[2 : 8]], 'Model' : 'KNN-Regression', 'Method' : sorted_results[-1][0], 'Percentage' : sorted_results[-1][1]}
    final_df = final_df.append(max_row, ignore_index = True)
    print("Maximum correct direction values are obtained for {} with a percentage of {}.".format(sorted_results[-1][0], sorted_results[-1][1]))
    return final_df

# %% [markdown]
# # Process of getting results

# %%
def create_pretty_table(name, model, method, result):
    values = [name[2 : 8 ] + "-" + companies[name[2 : 8]], method] + [round(v, 6) if (not isinstance(v, str)) else v for k,v in result.items()]
    tables[model].add_row(values)
    tables[model].title = model

# %%
columns =['Company','Method', 'RMSE','MAE','MSE','rsquared_adj','n_neighbors','weights','metric','Percentage']

# %%
# companies = {"500112" : "SBIN" ,
# "500325" : "RELIANCE INDUSTRIES LTD",
# "532540" : "TATA CONSULTANCY SERVICES LTD" ,
# "500209" : "INFOSYS LTD", 
# "532174" : "ICICI BANK LTD", 
# "507685" : "WIPRO LTD", 
# "530965" : "INDIAN OIL CORPORATION LTD", 
# "500182" : "HERO MOTOCORP LTD", 
# "532210" : "CITY UNION BANK LTD", 
# "500180" : "HDFC Bank Ltd",
# "500680" : "PFIZER LTD", 
# "506395" : "COROMANDEL iNTERNATIONAL LTD",
# "500770" : "TATA CHEMICALS LTD", 
# "500085" : "CHAMBAL FERTILISERS & CHEMICALS LTD", 
# "501425" : "BOMBAY BURMAH TRADING CORP.LTD", 
# "532899" : "KAVERI SEED COMPANY LTD", 
# "537291" : "NATH BIO-GENES (INDIA) LTD", 
# "500790" : "NESTLE INDIA LTD", 
# "500825" : "BRITANNIA INDUSTRIES LTD", 
# "533155" : "JUBILANT FOODWORKS LTD", 
# "533287" : "ZEE LEARN LTD", 
# "533260" : "CAREER POINT LTD", 
# "539921" : "SHANTI EDUCATIONAL INITIATIVES LTD", 
# "542602" : "EMBASSY OFFICE PARKS REIT", 
# "543217" : "MINDSPACE BUSINESS PARKS REIT", 
# "543261" : "BROOKFIELD INDIA REAL ESTATE TRUST REIT", 
# "532538" : "ULTRATECH CEMENT LTD", 
# "500387" : "SHREE CEMENT LTD", 
# "500425" : "AMBUJA CEMENTS LTD", 
# "532689" : "PVR LTD", 
# "532706" : "INOX LEISURE LTD", 
# "532163" : "SAREGAMA INDIA LTD", 
# "524715" : "SUN PHARMACEUTICAL INDUSTRIES LTD", 
# "532488" : "DIVI'S LABORATORIES LTD",
# "500124" : "DR.REDDY'S LABORATORIES LTD"}

# %%
df_equity = pd.read_csv("C:\\Users\\venu\\Desktop\\Stock Market Analysis\\Data\\Equity.csv")
security_numbers = df_equity["Security Code"].tolist()
security_names = df_equity["Security Name"].tolist()
companies = {str(k) : v for (k, v) in list(zip(security_numbers, security_names))}
companies["542602"] = "Embassy Office Parks REIT"
# companies["542602"]

# %%
models = ["KNN_Regression"]
tables = {model:PrettyTable() for model in models}
for name,table in tables.items():
    table.field_names = columns

# %%
final_df = pd.read_csv("C:\\Users\\venu\\Desktop\\Stock Market Analysis\\Data\\Models_Results\\All_Companies_Final_Results.csv")
# final_df.drop('Unnamed: 0', inplace = True, axis = 'columns')
final_df
# Out:
#                                        Company                   Model  \
# 0                     500002-ABB India Limited       Linear Regression
# 1                     500002-ABB India Limited        Ridge Regression
# 2                     500002-ABB India Limited        Lasso Regression
# 3                     500002-ABB India Limited  Elastic Net Regression
# 4                  500003-AEGIS LOGISTICS LTD.        Lasso Regression
# ..                                         ...                     ...
# 612  539921-Shanti Educational Initiatives Ltd        Lasso Regression
# 613           542602-Embassy Office Parks REIT        Lasso Regression
# 614           542602-Embassy Office Parks REIT  Elastic Net Regression
# 615           542602-Embassy Office Parks REIT       Linear Regression
# 616           542602-Embassy Office Parks REIT        Ridge Regression
#
#                       Method  Percentage
# 0            LinearFIFValue1    0.541713
# 1             RidgeFIFValue1    0.540601
# 2             LassoFIFValue1    0.537264
# 3           ElasticFIFValue1    0.536151
# 4          LassoFIFValue1000    0.539299
# ..                       ...         ...
# 612          LassoFIFValue10    0.495726
# 613         LassoFIPValue0.1    0.569231
# 614       ElasticFIPValue0.1    0.569231
# 615  LinearFICoefficients0.1    0.538462
# 616   RidgeFICoefficients0.1    0.538462
#
# [617 rows x 4 columns]

# %%
# %%time
for filename in os.listdir(os.path.join(path,"Data/Stock")):
    if filename.startswith("gr"):
        df_knn = pd.read_csv(os.path.join(path,"Data\Stock\\" + filename))
        name = os.path.join(path, "Data\Stock\\" + filename).split("\\")[-1]
        stock = name[2 : 8]
        fd_df = pd.DataFrame(columns = final_df.columns)
        print("For stock : ", stock)
        print("#################################################################################################################")
        f_df = get_results_from_each_set(df_knn, name, fd_df)
        final_df = final_df.append(f_df, ignore_index = True)
        print("#################################################################################################################")
#         break
        
final_df = final_df.sort_values(by = ['Company', 'Percentage'], ascending = [True, False])
final_df.to_csv('C:\\Users\\venu\\Desktop\\Stock Market Analysis\\Data\\Models_Results\\All_Companies_Final_Results.csv', index = False)
# Out:
# For stock :  500002
# #################################################################################################################
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['High Price GR', 'No. of Trades GR']
# KNN Model fitted using columns obtained from feature importance using ForwardSelection :
# 465 899 2995
# Percentage of correct direction :  0.5172413793103449
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['High Price GR', 'Low Price GR', 'No.of Shares GR', 'Total Turnover (Rs.) GR', 'Spread High-Low GR']
# KNN Model fitted using columns obtained from feature importance using BackwardElimination :
# 440 899 2995
# Percentage of correct direction :  0.489432703003337
# *****************************************************************************************
# All Features are considered :
# *****************************************************************************************
# All Features are --->>
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Alpha GR', 'Beta GR', 'Revenue GR', 'Dividend Value GR', 'Income GR', 'Expenditure GR', 'Net Profit GR', 'EPS GR']
# KNN Model fitted using columns obtained from feature importance using AllFeaturesConsideration :
# 463 899 2995
# Percentage of correct direction :  0.5150166852057843
# *****************************************************************************************
# Maximum correct direction values are obtained for KNN_Regression_FI_ForwardSelection_ with a percentage of 0.5172413793103449.
# #################################################################################################################
# For stock :  500003
# #################################################################################################################
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Beta GR', 'Low Price GR', 'Close Price GR', 'Open Price GR', 'Alpha GR', 'WAP GR', 'Spread High-Low GR', '% Deli. Qty to Traded Qty GR', 'No. of Trades GR']
# KNN Model fitted using columns obtained from feature importance using ForwardSelection :
# 390 827 2755
# Percentage of correct direction :  0.47158403869407495
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['Open Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No. of Trades GR', '% Deli. Qty to Traded Qty GR', 'Spread High-Low GR', 'Alpha GR', 'Beta GR']
# KNN Model fitted using columns obtained from feature importance using BackwardElimination :
# 390 827 2755
# Percentage of correct direction :  0.47158403869407495
# *****************************************************************************************
# All Features are considered :
# *****************************************************************************************
# All Features are --->>
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Alpha GR', 'Beta GR', 'Revenue GR', 'Dividend Value GR', 'Income GR', 'Expenditure GR', 'Net Profit GR', 'EPS GR']
# KNN Model fitted using columns obtained from feature importance using AllFeaturesConsideration :
# 439 827 2755
# Percentage of correct direction :  0.5308343409915357
# *****************************************************************************************
# Maximum correct direction values are obtained for KNN_Regression_FI_AllFeaturesConsideration_ with a percentage of 0.5308343409915357.
# #################################################################################################################
# For stock :  500008
# #################################################################################################################
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Beta GR', 'Close Price GR', 'Income GR']
# KNN Model fitted using columns obtained from feature importance using ForwardSelection :
# 460 895 2983
# Percentage of correct direction :  0.5139664804469274
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'No.of Shares GR', 'Total Turnover (Rs.) GR', 'Beta GR', 'Income GR']
# KNN Model fitted using columns obtained from feature importance using BackwardElimination :
# 443 895 2983
# Percentage of correct direction :  0.4949720670391061
# *****************************************************************************************
# All Features are considered :
# *****************************************************************************************
# All Features are --->>
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Alpha GR', 'Beta GR', 'Revenue GR', 'Dividend Value GR', 'Income GR', 'Expenditure GR', 'Net Profit GR', 'EPS GR']
# KNN Model fitted using columns obtained from feature importance using AllFeaturesConsideration :
# 451 895 2983
# Percentage of correct direction :  0.5039106145251396
# *****************************************************************************************
# Maximum correct direction values are obtained for KNN_Regression_FI_ForwardSelection_ with a percentage of 0.5139664804469274.
# #################################################################################################################
# For stock :  500009
# #################################################################################################################
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# []
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# []
# *****************************************************************************************
# All Features are considered :
# *****************************************************************************************
# All Features are --->>
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Beta GR', 'Revenue GR', 'Dividend Value GR', 'Income GR', 'Expenditure GR', 'Net Profit GR', 'EPS GR']
# KNN Model fitted using columns obtained from feature importance using AllFeaturesConsideration :
# 103 205 683
# Percentage of correct direction :  0.5024390243902439
# *****************************************************************************************
# Maximum correct direction values are obtained for KNN_Regression_FI_AllFeaturesConsideration_ with a percentage of 0.5024390243902439.
# #################################################################################################################
# For stock :  500010
# #################################################################################################################
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Beta GR', 'Low Price GR', 'Alpha GR', 'Open Price GR', 'Spread High-Low GR', 'Close Price GR']
# KNN Model fitted using columns obtained from feature importance using ForwardSelection :
# 382 776 2586
# Percentage of correct direction :  0.49226804123711343
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['Open Price GR', 'Low Price GR', 'Close Price GR', 'Spread High-Low GR', 'Alpha GR', 'Beta GR']
# KNN Model fitted using columns obtained from feature importance using BackwardElimination :
# 382 776 2586
# Percentage of correct direction :  0.49226804123711343
# *****************************************************************************************
# All Features are considered :
# *****************************************************************************************
# All Features are --->>
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Alpha GR', 'Beta GR', 'Revenue GR', 'Dividend Value GR', 'Income GR', 'Expenditure GR', 'Net Profit GR', 'EPS GR']
# KNN Model fitted using columns obtained from feature importance using AllFeaturesConsideration :
# 361 776 2586
# Percentage of correct direction :  0.4652061855670103
# *****************************************************************************************
# Maximum correct direction values are obtained for KNN_Regression_FI_BackwardElimination_ with a percentage of 0.49226804123711343.
# #################################################################################################################
# For stock :  500012
# #################################################################################################################
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Alpha GR', 'WAP GR']
# KNN Model fitted using columns obtained from feature importance using ForwardSelection :
# 225 432 1439
# Percentage of correct direction :  0.5208333333333334
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['High Price GR', 'Alpha GR']
# KNN Model fitted using columns obtained from feature importance using BackwardElimination :
# 228 432 1439
# Percentage of correct direction :  0.5277777777777778
# *****************************************************************************************
# All Features are considered :
# *****************************************************************************************
# All Features are --->>
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Alpha GR', 'Beta GR', 'Revenue GR', 'Dividend Value GR', 'Income GR', 'Expenditure GR', 'Net Profit GR', 'EPS GR']
# KNN Model fitted using columns obtained from feature importance using AllFeaturesConsideration :
# 212 432 1439
# Percentage of correct direction :  0.49074074074074076
# *****************************************************************************************
# Maximum correct direction values are obtained for KNN_Regression_FI_BackwardElimination_ with a percentage of 0.5277777777777778.
# #################################################################################################################
# For stock :  500013
# #################################################################################################################
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['WAP GR', 'Spread High-Low GR']
# KNN Model fitted using columns obtained from feature importance using ForwardSelection :
# 416 834 2778
# Percentage of correct direction :  0.4988009592326139
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['High Price GR', 'Close Price GR', 'WAP GR']
# KNN Model fitted using columns obtained from feature importance using BackwardElimination :
# 410 834 2778
# Percentage of correct direction :  0.49160671462829736
# *****************************************************************************************
# All Features are considered :
# *****************************************************************************************
# All Features are --->>
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Revenue GR', 'Dividend Value GR', 'Income GR', 'Expenditure GR', 'Net Profit GR', 'EPS GR']
# KNN Model fitted using columns obtained from feature importance using AllFeaturesConsideration :
# 398 834 2778
# Percentage of correct direction :  0.47721822541966424
# *****************************************************************************************
# Maximum correct direction values are obtained for KNN_Regression_FI_ForwardSelection_ with a percentage of 0.4988009592326139.
# #################################################################################################################
# For stock :  500020
# #################################################################################################################
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Beta GR', 'Close Price GR', 'Alpha GR']
# KNN Model fitted using columns obtained from feature importance using ForwardSelection :
# 452 885 2947
# Percentage of correct direction :  0.5107344632768361
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'Alpha GR', 'Beta GR']
# KNN Model fitted using columns obtained from feature importance using BackwardElimination :
# 452 885 2947
# Percentage of correct direction :  0.5107344632768361
# *****************************************************************************************
# All Features are considered :
# *****************************************************************************************
# All Features are --->>
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Alpha GR', 'Beta GR', 'Revenue GR', 'Dividend Value GR', 'Income GR', 'Expenditure GR', 'Net Profit GR', 'EPS GR']
# KNN Model fitted using columns obtained from feature importance using AllFeaturesConsideration :
# 469 885 2947
# Percentage of correct direction :  0.5299435028248588
# *****************************************************************************************
# Maximum correct direction values are obtained for KNN_Regression_FI_AllFeaturesConsideration_ with a percentage of 0.5299435028248588.
# #################################################################################################################
# For stock :  500023
# #################################################################################################################
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['High Price GR', 'WAP GR', 'Low Price GR']
# KNN Model fitted using columns obtained from feature importance using ForwardSelection :
# 453 843 2810
# Percentage of correct direction :  0.5373665480427047
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['High Price GR', 'Low Price GR', 'WAP GR']
# KNN Model fitted using columns obtained from feature importance using BackwardElimination :
# 453 843 2810
# Percentage of correct direction :  0.5373665480427047
# *****************************************************************************************
# All Features are considered :
# *****************************************************************************************
# All Features are --->>
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Revenue GR', 'Dividend Value GR', 'Income GR', 'Expenditure GR', 'Net Profit GR', 'EPS GR']
# KNN Model fitted using columns obtained from feature importance using AllFeaturesConsideration :
# 434 843 2810
# Percentage of correct direction :  0.5148279952550415
# *****************************************************************************************
# Maximum correct direction values are obtained for KNN_Regression_FI_BackwardElimination_ with a percentage of 0.5373665480427047.
# #################################################################################################################
# For stock :  500027
# #################################################################################################################
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Alpha GR', 'Beta GR', 'Open Price GR', 'High Price GR', 'WAP GR', 'Close Price GR']
# KNN Model fitted using columns obtained from feature importance using ForwardSelection :
# 460 893 2976
# Percentage of correct direction :  0.5151175811870101
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Close Price GR', 'WAP GR', 'Alpha GR', 'Beta GR', 'Net Profit GR', 'EPS GR']
# KNN Model fitted using columns obtained from feature importance using BackwardElimination :
# 451 893 2976
# Percentage of correct direction :  0.5050391937290034
# *****************************************************************************************
# All Features are considered :
# *****************************************************************************************
# All Features are --->>
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Alpha GR', 'Beta GR', 'Revenue GR', 'Dividend Value GR', 'Income GR', 'Expenditure GR', 'Net Profit GR', 'EPS GR']
# KNN Model fitted using columns obtained from feature importance using AllFeaturesConsideration :
# 455 893 2976
# Percentage of correct direction :  0.509518477043673
# *****************************************************************************************
# Maximum correct direction values are obtained for KNN_Regression_FI_ForwardSelection_ with a percentage of 0.5151175811870101.
# #################################################################################################################
# For stock :  500028
# #################################################################################################################
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['High Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR']
# KNN Model fitted using columns obtained from feature importance using ForwardSelection :
# 317 618 2059
# Percentage of correct direction :  0.5129449838187702
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['High Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'Dividend Value GR']
# KNN Model fitted using columns obtained from feature importance using BackwardElimination :
# 317 618 2059
# Percentage of correct direction :  0.5129449838187702
# *****************************************************************************************
# All Features are considered :
# *****************************************************************************************
# All Features are --->>
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Revenue GR', 'Dividend Value GR', 'Income GR', 'Expenditure GR', 'Net Profit GR', 'EPS GR']
# KNN Model fitted using columns obtained from feature importance using AllFeaturesConsideration :
# 325 618 2059
# Percentage of correct direction :  0.5258899676375405
# *****************************************************************************************
# Maximum correct direction values are obtained for KNN_Regression_FI_AllFeaturesConsideration_ with a percentage of 0.5258899676375405.
# #################################################################################################################
# For stock :  500031
# #################################################################################################################
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Close Price GR', 'Beta GR', 'Spread High-Low GR', 'Low Price GR', 'WAP GR']
# KNN Model fitted using columns obtained from feature importance using ForwardSelection :
# 441 878 2925
# Percentage of correct direction :  0.5022779043280182
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['Low Price GR', 'Close Price GR', 'WAP GR', 'Spread High-Low GR', 'Beta GR']
# KNN Model fitted using columns obtained from feature importance using BackwardElimination :
# 441 878 2925
# Percentage of correct direction :  0.5022779043280182
# *****************************************************************************************
# All Features are considered :
# *****************************************************************************************
# All Features are --->>
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Alpha GR', 'Beta GR', 'Revenue GR', 'Dividend Value GR', 'Income GR', 'Expenditure GR', 'Net Profit GR', 'EPS GR']
# KNN Model fitted using columns obtained from feature importance using AllFeaturesConsideration :
# 437 878 2925
# Percentage of correct direction :  0.4977220956719818
# *****************************************************************************************
# Maximum correct direction values are obtained for KNN_Regression_FI_BackwardElimination_ with a percentage of 0.5022779043280182.
# #################################################################################################################
# For stock :  500032
# #################################################################################################################
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Close Price GR', 'Spread Close-Open GR', 'WAP GR', 'Beta GR', 'Open Price GR']
# KNN Model fitted using columns obtained from feature importance using ForwardSelection :
# 402 805 2683
# Percentage of correct direction :  0.4993788819875776
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Close Price GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Beta GR']
# KNN Model fitted using columns obtained from feature importance using BackwardElimination :
# 408 805 2683
# Percentage of correct direction :  0.506832298136646
# *****************************************************************************************
# All Features are considered :
# *****************************************************************************************
# All Features are --->>
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Alpha GR', 'Beta GR', 'Revenue GR', 'Dividend Value GR', 'Income GR', 'Expenditure GR', 'Net Profit GR', 'EPS GR']
# KNN Model fitted using columns obtained from feature importance using AllFeaturesConsideration :
# 436 805 2683
# Percentage of correct direction :  0.5416149068322982
# *****************************************************************************************
# Maximum correct direction values are obtained for KNN_Regression_FI_AllFeaturesConsideration_ with a percentage of 0.5416149068322982.
# #################################################################################################################
# For stock :  500033
# #################################################################################################################
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Close Price GR']
# KNN Model fitted using columns obtained from feature importance using ForwardSelection :
# 364 741 2467
# Percentage of correct direction :  0.49122807017543857
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['Close Price GR']
# KNN Model fitted using columns obtained from feature importance using BackwardElimination :
# 364 741 2467
# Percentage of correct direction :  0.49122807017543857
# *****************************************************************************************
# All Features are considered :
# *****************************************************************************************
# All Features are --->>
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Alpha GR', 'Beta GR', 'Revenue GR', 'Dividend Value GR', 'Income GR', 'Expenditure GR', 'Net Profit GR', 'EPS GR']
# KNN Model fitted using columns obtained from feature importance using AllFeaturesConsideration :
# 371 741 2467
# Percentage of correct direction :  0.5006747638326585
# *****************************************************************************************
# Maximum correct direction values are obtained for KNN_Regression_FI_AllFeaturesConsideration_ with a percentage of 0.5006747638326585.
# #################################################################################################################
# For stock :  500034
# #################################################################################################################
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Low Price GR', 'Beta GR']
# KNN Model fitted using columns obtained from feature importance using ForwardSelection :
# 347 656 2186
# Percentage of correct direction :  0.5289634146341463
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['Close Price GR', 'Beta GR']
# KNN Model fitted using columns obtained from feature importance using BackwardElimination :
# 348 656 2186
# Percentage of correct direction :  0.5304878048780488
# *****************************************************************************************
# All Features are considered :
# *****************************************************************************************
# All Features are --->>
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Alpha GR', 'Beta GR', 'Revenue GR', 'Dividend Value GR', 'Income GR', 'Expenditure GR', 'Net Profit GR', 'EPS GR']
# KNN Model fitted using columns obtained from feature importance using AllFeaturesConsideration :
# 342 656 2186
# Percentage of correct direction :  0.5213414634146342
# *****************************************************************************************
# Maximum correct direction values are obtained for KNN_Regression_FI_BackwardElimination_ with a percentage of 0.5304878048780488.
# #################################################################################################################
# For stock :  500038
# #################################################################################################################
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Beta GR', 'High Price GR', 'EPS GR']
# KNN Model fitted using columns obtained from feature importance using ForwardSelection :
# 438 872 2904
# Percentage of correct direction :  0.5022935779816514
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['High Price GR', 'Beta GR', 'EPS GR']
# KNN Model fitted using columns obtained from feature importance using BackwardElimination :
# 438 872 2904
# Percentage of correct direction :  0.5022935779816514
# *****************************************************************************************
# All Features are considered :
# *****************************************************************************************
# All Features are --->>
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Alpha GR', 'Beta GR', 'Revenue GR', 'Dividend Value GR', 'Income GR', 'Expenditure GR', 'Net Profit GR', 'EPS GR']
# KNN Model fitted using columns obtained from feature importance using AllFeaturesConsideration :
# 409 872 2904
# Percentage of correct direction :  0.4690366972477064
# *****************************************************************************************
# Maximum correct direction values are obtained for KNN_Regression_FI_BackwardElimination_ with a percentage of 0.5022935779816514.
# #################################################################################################################
# For stock :  500039
# #################################################################################################################
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Beta GR', 'WAP GR', 'Income GR', 'Alpha GR']
# KNN Model fitted using columns obtained from feature importance using ForwardSelection :
# 433 837 2789
# Percentage of correct direction :  0.5173237753882916
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['WAP GR', 'No.of Shares GR', 'Total Turnover (Rs.) GR', 'Alpha GR', 'Beta GR', 'Income GR']
# KNN Model fitted using columns obtained from feature importance using BackwardElimination :
# 423 837 2789
# Percentage of correct direction :  0.5053763440860215
# *****************************************************************************************
# All Features are considered :
# *****************************************************************************************
# All Features are --->>
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Alpha GR', 'Beta GR', 'Revenue GR', 'Dividend Value GR', 'Income GR', 'Expenditure GR', 'Net Profit GR', 'EPS GR']
# KNN Model fitted using columns obtained from feature importance using AllFeaturesConsideration :
# 412 837 2789
# Percentage of correct direction :  0.4922341696535245
# *****************************************************************************************
# Maximum correct direction values are obtained for KNN_Regression_FI_ForwardSelection_ with a percentage of 0.5173237753882916.
# #################################################################################################################
# For stock :  500040
# #################################################################################################################
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Beta GR', 'WAP GR', 'High Price GR', 'Spread High-Low GR', 'Revenue GR']
# KNN Model fitted using columns obtained from feature importance using ForwardSelection :
# 417 831 2770
# Percentage of correct direction :  0.5018050541516246
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['High Price GR', 'WAP GR', 'Spread High-Low GR', 'Beta GR', 'Income GR', 'Net Profit GR', 'EPS GR']
# KNN Model fitted using columns obtained from feature importance using BackwardElimination :
# 415 831 2770
# Percentage of correct direction :  0.4993983152827918
# *****************************************************************************************
# All Features are considered :
# *****************************************************************************************
# All Features are --->>
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Alpha GR', 'Beta GR', 'Revenue GR', 'Dividend Value GR', 'Income GR', 'Expenditure GR', 'Net Profit GR', 'EPS GR']
# KNN Model fitted using columns obtained from feature importance using AllFeaturesConsideration :
# 424 831 2770
# Percentage of correct direction :  0.5102286401925391
# *****************************************************************************************
# Maximum correct direction values are obtained for KNN_Regression_FI_AllFeaturesConsideration_ with a percentage of 0.5102286401925391.
# #################################################################################################################
# For stock :  500041
# #################################################################################################################
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# []
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# []
# *****************************************************************************************
# All Features are considered :
# *****************************************************************************************
# All Features are --->>
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Revenue GR', 'Dividend Value GR', 'Income GR', 'Expenditure GR', 'Net Profit GR', 'EPS GR']
# KNN Model fitted using columns obtained from feature importance using AllFeaturesConsideration :
# 367 803 2676
# Percentage of correct direction :  0.45703611457036114
# *****************************************************************************************
# Maximum correct direction values are obtained for KNN_Regression_FI_AllFeaturesConsideration_ with a percentage of 0.45703611457036114.
# #################################################################################################################
# For stock :  500042
# #################################################################################################################
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['High Price GR', 'Open Price GR']
# KNN Model fitted using columns obtained from feature importance using ForwardSelection :
# 388 760 2531
# Percentage of correct direction :  0.5105263157894737
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'No. of Trades GR']
# KNN Model fitted using columns obtained from feature importance using BackwardElimination :
# 381 760 2531
# Percentage of correct direction :  0.5013157894736842
# *****************************************************************************************
# All Features are considered :
# *****************************************************************************************
# All Features are --->>
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Alpha GR', 'Beta GR', 'Revenue GR', 'Dividend Value GR', 'Income GR', 'Expenditure GR', 'Net Profit GR', 'EPS GR']
# KNN Model fitted using columns obtained from feature importance using AllFeaturesConsideration :
# 358 760 2531
# Percentage of correct direction :  0.4710526315789474
# *****************************************************************************************
# Maximum correct direction values are obtained for KNN_Regression_FI_ForwardSelection_ with a percentage of 0.5105263157894737.
# #################################################################################################################
# For stock :  500043
# #################################################################################################################
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Beta GR', 'Close Price GR', 'Alpha GR', 'No. of Trades GR', 'Low Price GR', 'Open Price GR']
# KNN Model fitted using columns obtained from feature importance using ForwardSelection :
# 442 897 2990
# Percentage of correct direction :  0.4927536231884058
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['Open Price GR', 'Low Price GR', 'Close Price GR', 'No.of Shares GR', 'Alpha GR', 'Beta GR']
# KNN Model fitted using columns obtained from feature importance using BackwardElimination :
# 468 897 2990
# Percentage of correct direction :  0.5217391304347826
# *****************************************************************************************
# All Features are considered :
# *****************************************************************************************
# All Features are --->>
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Alpha GR', 'Beta GR', 'Revenue GR', 'Dividend Value GR', 'Income GR', 'Expenditure GR', 'Net Profit GR', 'EPS GR']
# KNN Model fitted using columns obtained from feature importance using AllFeaturesConsideration :
# 420 897 2990
# Percentage of correct direction :  0.4682274247491639
# *****************************************************************************************
# Maximum correct direction values are obtained for KNN_Regression_FI_BackwardElimination_ with a percentage of 0.5217391304347826.
# #################################################################################################################
# For stock :  500048
# #################################################################################################################
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Close Price GR', 'No. of Trades GR', 'WAP GR']
# KNN Model fitted using columns obtained from feature importance using ForwardSelection :
# 464 897 2990
# Percentage of correct direction :  0.5172798216276477
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['Close Price GR', 'WAP GR', 'No. of Trades GR']
# ...
# #################################################################################################################
# For stock :  532899
# #################################################################################################################
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Low Price GR', 'High Price GR', 'Spread High-Low GR', 'Beta GR', 'Open Price GR', 'Close Price GR']
# KNN Model fitted using columns obtained from feature importance using ForwardSelection :
# 395 778 2593
# Percentage of correct direction :  0.5077120822622108
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'Spread High-Low GR', 'Beta GR']
# KNN Model fitted using columns obtained from feature importance using BackwardElimination :
# 395 778 2593
# Percentage of correct direction :  0.5077120822622108
# *****************************************************************************************
# All Features are considered :
# *****************************************************************************************
# All Features are --->>
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Alpha GR', 'Beta GR', 'Revenue GR', 'Dividend Value GR', 'Income GR', 'Expenditure GR', 'Net Profit GR', 'EPS GR']
# KNN Model fitted using columns obtained from feature importance using AllFeaturesConsideration :
# 391 778 2593
# Percentage of correct direction :  0.5025706940874036
# *****************************************************************************************
# Maximum correct direction values are obtained for KNN_Regression_FI_BackwardElimination_ with a percentage of 0.5077120822622108.
# #################################################################################################################
# For stock :  533155
# #################################################################################################################
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['High Price GR', 'Beta GR', 'Open Price GR']
# KNN Model fitted using columns obtained from feature importance using ForwardSelection :
# 382 712 2371
# Percentage of correct direction :  0.5365168539325843
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Beta GR']
# KNN Model fitted using columns obtained from feature importance using BackwardElimination :
# 382 712 2371
# Percentage of correct direction :  0.5365168539325843
# *****************************************************************************************
# All Features are considered :
# *****************************************************************************************
# All Features are --->>
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Alpha GR', 'Beta GR', 'Revenue GR', 'Dividend Value GR', 'Income GR', 'Expenditure GR', 'Net Profit GR', 'EPS GR']
# KNN Model fitted using columns obtained from feature importance using AllFeaturesConsideration :
# 343 712 2371
# Percentage of correct direction :  0.48174157303370785
# *****************************************************************************************
# Maximum correct direction values are obtained for KNN_Regression_FI_BackwardElimination_ with a percentage of 0.5365168539325843.
# #################################################################################################################
# For stock :  533260
# #################################################################################################################
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Net Profit GR']
# KNN Model fitted using columns obtained from feature importance using ForwardSelection :
# 330 643 2142
# Percentage of correct direction :  0.5132192846034215
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'WAP GR', 'Net Profit GR']
# KNN Model fitted using columns obtained from feature importance using BackwardElimination :
# 324 643 2142
# Percentage of correct direction :  0.5038880248833593
# *****************************************************************************************
# All Features are considered :
# *****************************************************************************************
# All Features are --->>
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Revenue GR', 'Dividend Value GR', 'Income GR', 'Expenditure GR', 'Net Profit GR', 'EPS GR']
# KNN Model fitted using columns obtained from feature importance using AllFeaturesConsideration :
# 319 643 2142
# Percentage of correct direction :  0.49611197511664074
# *****************************************************************************************
# Maximum correct direction values are obtained for KNN_Regression_FI_ForwardSelection_ with a percentage of 0.5132192846034215.
# #################################################################################################################
# For stock :  533287
# #################################################################################################################
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Alpha GR', 'Close Price GR', 'Open Price GR', 'No. of Trades GR', 'Expenditure GR']
# KNN Model fitted using columns obtained from feature importance using ForwardSelection :
# 306 626 2084
# Percentage of correct direction :  0.48881789137380194
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['Open Price GR', 'Close Price GR', 'No. of Trades GR', 'Alpha GR', 'Expenditure GR']
# KNN Model fitted using columns obtained from feature importance using BackwardElimination :
# 306 626 2084
# Percentage of correct direction :  0.48881789137380194
# *****************************************************************************************
# All Features are considered :
# *****************************************************************************************
# All Features are --->>
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Alpha GR', 'Beta GR', 'Revenue GR', 'Dividend Value GR', 'Income GR', 'Expenditure GR', 'Net Profit GR', 'EPS GR']
# KNN Model fitted using columns obtained from feature importance using AllFeaturesConsideration :
# 313 626 2084
# Percentage of correct direction :  0.5
# *****************************************************************************************
# Maximum correct direction values are obtained for KNN_Regression_FI_AllFeaturesConsideration_ with a percentage of 0.5.
# #################################################################################################################
# For stock :  537291
# #################################################################################################################
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['WAP GR', 'Income GR']
# KNN Model fitted using columns obtained from feature importance using ForwardSelection :
# 206 424 1413
# Percentage of correct direction :  0.4858490566037736
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['Low Price GR', 'Close Price GR', 'WAP GR', 'No. of Trades GR', 'Dividend Value GR']
# KNN Model fitted using columns obtained from feature importance using BackwardElimination :
# 216 424 1413
# Percentage of correct direction :  0.5094339622641509
# *****************************************************************************************
# All Features are considered :
# *****************************************************************************************
# All Features are --->>
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Revenue GR', 'Dividend Value GR', 'Income GR', 'Expenditure GR', 'Net Profit GR', 'EPS GR']
# KNN Model fitted using columns obtained from feature importance using AllFeaturesConsideration :
# 197 424 1413
# Percentage of correct direction :  0.46462264150943394
# *****************************************************************************************
# Maximum correct direction values are obtained for KNN_Regression_FI_BackwardElimination_ with a percentage of 0.5094339622641509.
# #################################################################################################################
# For stock :  539921
# #################################################################################################################
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Close Price GR', 'Deliverable Quantity GR', 'WAP GR', 'Low Price GR', 'Spread High-Low GR', 'No. of Trades GR']
# KNN Model fitted using columns obtained from feature importance using ForwardSelection :
# 74 117 388
# Percentage of correct direction :  0.6324786324786325
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'WAP GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Dividend Value GR']
# KNN Model fitted using columns obtained from feature importance using BackwardElimination :
# 80 117 388
# Percentage of correct direction :  0.6837606837606838
# *****************************************************************************************
# All Features are considered :
# *****************************************************************************************
# All Features are --->>
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Dividend Value GR']
# KNN Model fitted using columns obtained from feature importance using AllFeaturesConsideration :
# 78 117 388
# Percentage of correct direction :  0.6666666666666666
# *****************************************************************************************
# Maximum correct direction values are obtained for KNN_Regression_FI_BackwardElimination_ with a percentage of 0.6837606837606838.
# #################################################################################################################
# For stock :  542602
# #################################################################################################################
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Open Price GR']
# KNN Model fitted using columns obtained from feature importance using ForwardSelection :
# 57 130 431
# Percentage of correct direction :  0.43846153846153846
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['Open Price GR', 'Dividend Value GR']
# KNN Model fitted using columns obtained from feature importance using BackwardElimination :
# 57 130 431
# Percentage of correct direction :  0.43846153846153846
# *****************************************************************************************
# All Features are considered :
# *****************************************************************************************
# All Features are --->>
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Alpha GR', 'Beta GR', 'Dividend Value GR']
# KNN Model fitted using columns obtained from feature importance using AllFeaturesConsideration :
# 69 130 431
# Percentage of correct direction :  0.5307692307692308
# *****************************************************************************************
# Maximum correct direction values are obtained for KNN_Regression_FI_AllFeaturesConsideration_ with a percentage of 0.5307692307692308.
# #################################################################################################################
# Wall time: 1h 44min 51s

# %%
# %%time

# mydf = pd.DataFrame(columns=columns)
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         filepath = os.path.join(dirname, filename)
#         df = pd.read_csv(filepath)
#         df = pre_process_data(df,60)
#         column = "Next Day Close Price GR"
#         (df,column) = dependent_column(df,column)
#         X = df.drop(columns=[column])
#         Y = df[column]
#         result = k_nearest_neighbours(X,Y)
#         result.update({"Company":filename[2:8] + "-" + companies[filename[2:8]]})
#         mydf = mydf.append(result,ignore_index=True)
# mydf.to_csv(os.path.join(os.getcwd(),"best_knn"+".csv"),index=None)

# %%
for name,table in tables.items():
    print(table)
# Out:
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |                                                                                  KNN_Regression                                                                                 |
# +-------------------------------------------------+---------------------------+-----------+----------+-------------+--------------+-------------+---------+----------+------------+
# |                     Company                     |           Method          |    RMSE   |   MAE    |     MSE     | rsquared_adj | n_neighbors | weights |  metric  | Percentage |
# +-------------------------------------------------+---------------------------+-----------+----------+-------------+--------------+-------------+---------+----------+------------+
# |             500002-ABB India Limited            |     ForwardSelection      |  0.02226  | 0.014846 |   0.000496  |  -0.012189   |  manhattan  |   101   | uniform  |  0.517241  |
# |             500002-ABB India Limited            |    BackwardElimination    |  0.022328 | 0.014875 |   0.000499  |  -0.018348   |  euclidean  |    98   | uniform  |  0.489433  |
# |             500002-ABB India Limited            | AllFeaturesConsideration  |  0.022119 | 0.014764 |   0.000489  |   0.000649   |  manhattan  |    71   | uniform  |  0.515017  |
# |           500003-AEGIS LOGISTICS LTD.           |     ForwardSelection      |  0.037227 | 0.024501 |   0.001386  |  -0.009842   |  manhattan  |   105   | uniform  |  0.471584  |
# |           500003-AEGIS LOGISTICS LTD.           |    BackwardElimination    |  0.037227 | 0.024501 |   0.001386  |  -0.009842   |  manhattan  |   105   | uniform  |  0.471584  |
# |           500003-AEGIS LOGISTICS LTD.           | AllFeaturesConsideration  |  0.036934 | 0.024146 |   0.001364  |   0.005976   |  manhattan  |   104   | uniform  |  0.530834  |
# |         500008-AMARA RAJA BATTERIES LTD.        |     ForwardSelection      |  0.130529 | 0.020805 |   0.017038  |  -0.002993   |  manhattan  |   102   | uniform  |  0.513966  |
# |         500008-AMARA RAJA BATTERIES LTD.        |    BackwardElimination    |  0.130438 | 0.020723 |   0.017014  |  -0.001602   |  manhattan  |   105   | uniform  |  0.494972  |
# |         500008-AMARA RAJA BATTERIES LTD.        | AllFeaturesConsideration  |  0.130374 | 0.020677 |   0.016997  |  -0.000617   |  manhattan  |   104   | uniform  |  0.503911  |
# |     500009-AMBALAL SARABHAI ENTERPRISES LTD.    | AllFeaturesConsideration  |  0.03905  | 0.028829 |   0.001525  |   0.027593   |  manhattan  |    57   | uniform  |  0.502439  |
# |   500010-HOUSING DEVELOPMENT FINANCE CORP.LTD.  |     ForwardSelection      |  0.13992  | 0.020385 |   0.019578  |   -0.00252   |  euclidean  |   104   | uniform  |  0.492268  |
# |   500010-HOUSING DEVELOPMENT FINANCE CORP.LTD.  |    BackwardElimination    |  0.13992  | 0.020385 |   0.019578  |   -0.00252   |  euclidean  |   104   | uniform  |  0.492268  |
# |   500010-HOUSING DEVELOPMENT FINANCE CORP.LTD.  | AllFeaturesConsideration  |  0.139969 | 0.020475 |   0.019591  |  -0.003227   |  manhattan  |   105   | uniform  |  0.465206  |
# |        500012-ANDHRA PETROCHEMICALS LTD.        |     ForwardSelection      |  0.034722 | 0.025407 |   0.001206  |   0.000835   |  euclidean  |   105   | uniform  |  0.520833  |
# |        500012-ANDHRA PETROCHEMICALS LTD.        |    BackwardElimination    |  0.034686 | 0.025308 |   0.001203  |   0.002935   |  manhattan  |   101   | uniform  |  0.527778  |
# |        500012-ANDHRA PETROCHEMICALS LTD.        | AllFeaturesConsideration  |  0.035105 | 0.025549 |   0.001232  |  -0.021309   |  euclidean  |   105   | uniform  |  0.490741  |
# |  500013-ANSAL PROPERTIES & INFRASTRUCTURE LTD.  |     ForwardSelection      |  0.037145 | 0.027344 |   0.00138   |   0.000126   |  euclidean  |    92   | uniform  |  0.498801  |
# |  500013-ANSAL PROPERTIES & INFRASTRUCTURE LTD.  |    BackwardElimination    |  0.037415 | 0.027595 |    0.0014   |   -0.01446   |  euclidean  |   103   | uniform  |  0.491607  |
# |  500013-ANSAL PROPERTIES & INFRASTRUCTURE LTD.  | AllFeaturesConsideration  |  0.037429 | 0.027517 |   0.001401  |  -0.015239   |  manhattan  |    96   | uniform  |  0.477218  |
# |        500020-BOMBAY DYEING & MFG.CO.LTD.       |     ForwardSelection      |  0.033661 | 0.024246 |   0.001133  |  -0.000766   |  manhattan  |    99   | uniform  |  0.510734  |
# |        500020-BOMBAY DYEING & MFG.CO.LTD.       |    BackwardElimination    |  0.033453 | 0.024189 |   0.001119  |   0.01153    |  euclidean  |   105   | uniform  |  0.510734  |
# |        500020-BOMBAY DYEING & MFG.CO.LTD.       | AllFeaturesConsideration  |  0.033547 | 0.024197 |   0.001125  |   0.005975   |  manhattan  |    66   | uniform  |  0.529944  |
# |       500023-Asian Hotels (North) Limited       |     ForwardSelection      |  0.121687 | 0.025693 |   0.014808  |  -0.001146   |  euclidean  |    98   | uniform  |  0.537367  |
# |       500023-Asian Hotels (North) Limited       |    BackwardElimination    |  0.121687 | 0.025693 |   0.014808  |  -0.001146   |  euclidean  |    98   | uniform  |  0.537367  |
# |       500023-Asian Hotels (North) Limited       | AllFeaturesConsideration  |  0.12169  | 0.025875 |   0.014808  |  -0.001193   |  manhattan  |    85   | uniform  |  0.514828  |
# |                 500027-ATUL LTD.                |     ForwardSelection      |  0.024542 | 0.017209 |   0.000602  |   0.023821   |  euclidean  |    76   | distance |  0.515118  |
# |                 500027-ATUL LTD.                |    BackwardElimination    |  0.024908 | 0.017291 |   0.00062   |  -0.005535   |  manhattan  |    80   | uniform  |  0.505039  |
# |                 500027-ATUL LTD.                | AllFeaturesConsideration  |  0.024867 | 0.017277 |   0.000618  |  -0.002197   |  manhattan  |   105   | uniform  |  0.509518  |
# |          500028-ATV PROJECTS INDIA LTD.         |     ForwardSelection      |  0.049979 | 0.030307 |   0.002498  |  -0.005628   |  euclidean  |    66   | uniform  |  0.512945  |
# |          500028-ATV PROJECTS INDIA LTD.         |    BackwardElimination    |  0.049979 | 0.030307 |   0.002498  |  -0.005628   |  euclidean  |    66   | uniform  |  0.512945  |
# |          500028-ATV PROJECTS INDIA LTD.         | AllFeaturesConsideration  |  0.050036 | 0.030321 |   0.002504  |  -0.007923   |  euclidean  |    98   | distance |  0.52589   |
# |         500031-BAJAJ ELECTRICALS LTD.-$         |     ForwardSelection      |  0.026102 | 0.018613 |   0.000681  |  -0.005208   |  euclidean  |    96   | uniform  |  0.502278  |
# |         500031-BAJAJ ELECTRICALS LTD.-$         |    BackwardElimination    |  0.026102 | 0.018613 |   0.000681  |  -0.005208   |  euclidean  |    96   | uniform  |  0.502278  |
# |         500031-BAJAJ ELECTRICALS LTD.-$         | AllFeaturesConsideration  |  0.026422 | 0.019132 |   0.000698  |  -0.030012   |  manhattan  |    41   | distance |  0.497722  |
# |      500032-Bajaj Hindusthan Sugar Limited      |     ForwardSelection      |  0.040038 | 0.026641 |   0.001603  |  -0.003835   |  manhattan  |    98   | uniform  |  0.499379  |
# |      500032-Bajaj Hindusthan Sugar Limited      |    BackwardElimination    |  0.040022 | 0.026692 |   0.001602  |  -0.003032   |  manhattan  |    87   | uniform  |  0.506832  |
# |      500032-Bajaj Hindusthan Sugar Limited      | AllFeaturesConsideration  |  0.040059 | 0.026733 |   0.001605  |  -0.004875   |  euclidean  |    79   | uniform  |  0.541615  |
# |            500033-FORCE MOTORS LTD.-$           |     ForwardSelection      |  0.027701 | 0.019101 |   0.000767  |  -0.014904   |  euclidean  |    98   | uniform  |  0.491228  |
# |            500033-FORCE MOTORS LTD.-$           |    BackwardElimination    |  0.027701 | 0.019101 |   0.000767  |  -0.014904   |  euclidean  |    98   | uniform  |  0.491228  |
# |            500033-FORCE MOTORS LTD.-$           | AllFeaturesConsideration  |  0.027491 | 0.018927 |   0.000756  |   0.000428   |  manhattan  |    79   | uniform  |  0.500675  |
# |           500034-Bajaj Finance Limited          |     ForwardSelection      |  0.344673 | 0.029126 |    0.1188   |  -0.001962   |  manhattan  |   105   | uniform  |  0.528963  |
# |           500034-Bajaj Finance Limited          |    BackwardElimination    |  0.344792 | 0.02909  |   0.118882  |  -0.002656   |  euclidean  |   105   | uniform  |  0.530488  |
# |                 500048-BEML LTD.                |     ForwardSelection      |  0.027609 | 0.01885  |   0.000762  |   0.003151   |  manhattan  |   105   | distance |  0.51728   |
# |                 500048-BEML LTD.                |    BackwardElimination    |  0.027609 | 0.01885  |   0.000762  |   0.003151   |  manhattan  |   105   | distance |  0.51728   |
# |                 500048-BEML LTD.                | AllFeaturesConsideration  |  0.027661 | 0.01874  |   0.000765  |   -0.00066   |  manhattan  |    99   | distance |  0.512821  |
# |          500049-BHARAT ELECTRONICS LTD.         |     ForwardSelection      |  0.022162 | 0.015787 |   0.000491  |  -0.010256   |  euclidean  |   104   | uniform  |  0.517817  |
# |          500049-BHARAT ELECTRONICS LTD.         |    BackwardElimination    |  0.02236  | 0.01604  |    0.0005   |  -0.028363   |  manhattan  |    77   | uniform  |  0.482183  |
# |          500049-BHARAT ELECTRONICS LTD.         | AllFeaturesConsideration  |  0.022159 | 0.015849 |   0.000491  |  -0.009953   |  manhattan  |   105   | uniform  |  0.492205  |
# |   500052-BHANSALI ENGINEERING POLYMERS LTD.-$   |     ForwardSelection      |  0.035774 | 0.026279 |   0.00128   |   0.007376   |  euclidean  |    95   | uniform  |  0.526596  |
# |   500052-BHANSALI ENGINEERING POLYMERS LTD.-$   |    BackwardElimination    |  0.035774 | 0.026279 |   0.00128   |   0.007376   |  euclidean  |    95   | uniform  |  0.526596  |
# |   500052-BHANSALI ENGINEERING POLYMERS LTD.-$   | AllFeaturesConsideration  |  0.036044 | 0.026329 |   0.001299  |  -0.007659   |  manhattan  |   102   | uniform  |  0.518617  |
# |            500055-Tata Steel Bsl Ltd            |     ForwardSelection      |  0.136157 | 0.025445 |   0.018539  |  -0.003095   |  manhattan  |    34   | uniform  |  0.504577  |
# |            500055-Tata Steel Bsl Ltd            |    BackwardElimination    |  0.136081 | 0.025047 |   0.018518  |  -0.001982   |  euclidean  |   104   | uniform  |  0.521739  |
# |            500055-Tata Steel Bsl Ltd            | AllFeaturesConsideration  |  0.136023 | 0.025208 |   0.018502  |  -0.001124   |  manhattan  |   105   | uniform  |  0.520595  |
# |              500060-Birla Cable Ltd             |     ForwardSelection      |  0.037344 | 0.027854 |   0.001395  |   0.003366   |  euclidean  |   105   | uniform  |  0.501124  |
# |              500060-Birla Cable Ltd             |    BackwardElimination    |  0.037368 | 0.027854 |   0.001396  |   0.002044   |  euclidean  |    96   | uniform  |  0.507865  |
# |              500060-Birla Cable Ltd             | AllFeaturesConsideration  |  0.037618 | 0.028041 |   0.001415  |   -0.01136   |  manhattan  |    94   | uniform  |  0.489888  |
# |              500067-BLUE STAR LTD.              |     ForwardSelection      |  0.021045 | 0.014872 |   0.000443  |   0.013109   |  euclidean  |   104   | uniform  |  0.53915   |
# |              500067-BLUE STAR LTD.              |    BackwardElimination    |  0.021045 | 0.014872 |   0.000443  |   0.013109   |  euclidean  |   104   | uniform  |  0.53915   |
# |              500067-BLUE STAR LTD.              | AllFeaturesConsideration  |  0.021407 | 0.015206 |   0.000458  |  -0.021161   |  manhattan  |    77   | uniform  |  0.488814  |
# |              500068-DISA INDIA LTD.             |     ForwardSelection      |  0.024653 | 0.016175 |   0.000608  |  -0.012037   |  euclidean  |    95   | uniform  |  0.482838  |
# |              500068-DISA INDIA LTD.             |    BackwardElimination    |  0.024534 | 0.015951 |   0.000602  |  -0.002282   |  manhattan  |   101   | uniform  |  0.497712  |
# |              500068-DISA INDIA LTD.             | AllFeaturesConsideration  |  0.02467  |  0.0161  |   0.000609  |  -0.013476   |  manhattan  |   105   | uniform  |  0.491991  |
# |         500069-BNK CAPITAL MARKETS LTD.         | AllFeaturesConsideration  |  2.984261 | 0.140775 |   8.905813  |  -0.001329   |  manhattan  |   103   | uniform  |  0.492414  |
# |                 500074-BPL LTD.                 |     ForwardSelection      |  0.037279 | 0.026881 |   0.00139   |   0.00113    |  manhattan  |   105   | uniform  |  0.487211  |
# |                 500074-BPL LTD.                 |    BackwardElimination    |  0.037395 | 0.026754 |   0.001398  |  -0.005109   |  manhattan  |   105   | distance |  0.542022  |
# |                 500074-BPL LTD.                 | AllFeaturesConsideration  |  0.037587 | 0.026969 |   0.001413  |  -0.015445   |  manhattan  |   100   | distance |  0.507917  |
# |         500078-Oriental Aromatics Ltd-$         |     ForwardSelection      |  0.059255 | 0.03038  |   0.003511  |  -1.843605   |  euclidean  |   105   | uniform  |  0.486207  |
# |         500078-Oriental Aromatics Ltd-$         |    BackwardElimination    |  0.059255 | 0.03038  |   0.003511  |  -1.843605   |  euclidean  |   105   | uniform  |  0.486207  |
# |         500078-Oriental Aromatics Ltd-$         | AllFeaturesConsideration  |  0.058247 | 0.030062 |   0.003393  |   -1.74764   |  euclidean  |   105   | uniform  |  0.481609  |
# |          500083-CENTURY EXTRUSIONS LTD.         |     ForwardSelection      | 54.375281 | 2.031825 | 2956.671209 |  -0.001372   |  manhattan  |    45   | distance |  0.514905  |
# |          500083-CENTURY EXTRUSIONS LTD.         |    BackwardElimination    | 54.375281 | 2.031825 | 2956.671209 |  -0.001372   |  manhattan  |    45   | distance |  0.514905  |
# |          500083-CENTURY EXTRUSIONS LTD.         | AllFeaturesConsideration  | 54.371742 | 2.035249 |  2956.28638 |  -0.001241   |  euclidean  |    5    | uniform  |  0.479675  |
# |                 500084-CESC LTD.                |     ForwardSelection      |  0.023271 | 0.015967 |   0.000542  |  -0.012806   |  euclidean  |    92   | uniform  |  0.508681  |
# |                 500084-CESC LTD.                |    BackwardElimination    |  0.023175 | 0.015901 |   0.000537  |  -0.004487   |  euclidean  |    83   | uniform  |  0.503472  |
# |                 500084-CESC LTD.                | AllFeaturesConsideration  |  0.023222 | 0.015928 |   0.000539  |  -0.008536   |  euclidean  |    94   | uniform  |  0.482639  |
# |   500085-CHAMBAL FERTILISERS & CHEMICALS LTD.   |     ForwardSelection      |  0.030449 | 0.02043  |   0.000927  |  -0.010911   |  euclidean  |    84   | uniform  |  0.52445   |
# |   500085-CHAMBAL FERTILISERS & CHEMICALS LTD.   |    BackwardElimination    |  0.030449 | 0.02043  |   0.000927  |  -0.010911   |  euclidean  |    84   | uniform  |  0.52445   |
# |   500085-CHAMBAL FERTILISERS & CHEMICALS LTD.   | AllFeaturesConsideration  |  0.030543 | 0.020555 |   0.000933  |   -0.01716   |  euclidean  |   101   | uniform  |  0.487775  |
# |           500086-EXIDE INDUSTRIES LTD.          |     ForwardSelection      |  0.022392 | 0.016323 |   0.000501  |  -0.024462   |  manhattan  |   102   | distance |  0.519641  |
# |           500086-EXIDE INDUSTRIES LTD.          |    BackwardElimination    |  0.022392 | 0.016323 |   0.000501  |  -0.024462   |  manhattan  |   102   | distance |  0.519641  |
# |           500086-EXIDE INDUSTRIES LTD.          | AllFeaturesConsideration  |  0.022196 | 0.016336 |   0.000493  |  -0.006675   |  euclidean  |    83   | uniform  |  0.482604  |
# |                500087-CIPLA LTD.                |     ForwardSelection      |  0.018217 | 0.012725 |   0.000332  |  -0.013394   |  euclidean  |    99   | uniform  |  0.467113  |
# |                500087-CIPLA LTD.                |    BackwardElimination    |  0.018282 | 0.012853 |   0.000334  |  -0.020648   |  manhattan  |    77   | distance |  0.45039   |
# |                500087-CIPLA LTD.                | AllFeaturesConsideration  |  0.018274 | 0.012733 |   0.000334  |   -0.01975   |  manhattan  |    96   | uniform  |  0.483835  |
# |              500089-DIC INDIA LTD.              |    BackwardElimination    |  0.027241 | 0.018702 |   0.000742  |  -0.094407   |  euclidean  |    6    | uniform  |  0.522581  |
# |              500089-DIC INDIA LTD.              | AllFeaturesConsideration  |  0.266373 | 0.034615 |   0.070954  | -103.641217  |  euclidean  |    5    | uniform  |  0.476129  |
# |                500092-CRISIL LTD.               |     ForwardSelection      |  0.316395 | 0.025771 |   0.100106  |  -0.003548   |  manhattan  |   105   | distance |  0.505141  |
# |                500092-CRISIL LTD.               |    BackwardElimination    |  0.316395 | 0.025771 |   0.100106  |  -0.003548   |  manhattan  |   105   | distance |  0.505141  |
# |                500092-CRISIL LTD.               | AllFeaturesConsideration  |  0.316753 | 0.027232 |   0.100333  |  -0.005822   |  manhattan  |   105   | uniform  |  0.482005  |
# |   500093-CG Power and Industrial Solutions Ltd  |     ForwardSelection      |  0.03981  | 0.022508 |   0.001585  |  -0.000309   |  manhattan  |    98   | uniform  |  0.489093  |
# |   500093-CG Power and Industrial Solutions Ltd  |    BackwardElimination    |  0.03981  | 0.022508 |   0.001585  |  -0.000309   |  manhattan  |    98   | uniform  |  0.489093  |
# |   500093-CG Power and Industrial Solutions Ltd  | AllFeaturesConsideration  |  0.039976 | 0.022702 |   0.001598  |  -0.008703   |  manhattan  |    98   | distance |  0.476464  |
# |             500096-DABUR INDIA LTD.             |     ForwardSelection      |  0.016375 | 0.011882 |   0.000268  |  -0.007468   |  euclidean  |    92   | uniform  |  0.506726  |
# |             500096-DABUR INDIA LTD.             |    BackwardElimination    |  0.016512 | 0.012009 |   0.000273  |  -0.024392   |  manhattan  |   105   | uniform  |  0.474215  |
# |         500123-ELANTAS BECK INDIA LTD.-$        |    BackwardElimination    |  0.029359 | 0.018939 |   0.000862  |  -0.021119   |  manhattan  |    87   | uniform  |  0.463883  |
# |         500123-ELANTAS BECK INDIA LTD.-$        | AllFeaturesConsideration  |  0.029153 | 0.018823 |   0.00085   |  -0.006842   |  euclidean  |   102   | uniform  |  0.497743  |
# |     500124-DR.REDDY&#39;S LABORATORIES LTD.     |     ForwardSelection      |  0.018639 | 0.013356 |   0.000347  |  -0.018813   |  manhattan  |    95   | uniform  |  0.492063  |
# |     500124-DR.REDDY&#39;S LABORATORIES LTD.     |    BackwardElimination    |  0.018584 | 0.013351 |   0.000345  |  -0.012827   |  euclidean  |    98   | uniform  |  0.488662  |
# |     500124-DR.REDDY&#39;S LABORATORIES LTD.     | AllFeaturesConsideration  |  0.018538 | 0.013259 |   0.000344  |  -0.007815   |  euclidean  |    98   | uniform  |  0.504535  |
# |         500125-E.I.D.-PARRY (INDIA) LTD.        |     ForwardSelection      |  0.026188 | 0.018481 |   0.000686  |  -0.005537   |  euclidean  |   104   | uniform  |  0.481027  |
# |         500125-E.I.D.-PARRY (INDIA) LTD.        |    BackwardElimination    |  0.02631  | 0.018566 |   0.000692  |  -0.014877   |  euclidean  |    91   | uniform  |  0.469866  |
# |         500125-E.I.D.-PARRY (INDIA) LTD.        | AllFeaturesConsideration  |  0.026359 | 0.018657 |   0.000695  |  -0.018722   |  manhattan  |    66   | uniform  |  0.477679  |
# |        500126-Procter & Gamble Health Ltd       |     ForwardSelection      |  0.019213 | 0.012921 |   0.000369  |   0.004572   |  euclidean  |   104   | uniform  |  0.492433  |
# |        500126-Procter & Gamble Health Ltd       |    BackwardElimination    |   0.0193  | 0.012929 |   0.000372  |  -0.004523   |  manhattan  |    99   | distance |  0.491269  |
# |        500126-Procter & Gamble Health Ltd       | AllFeaturesConsideration  |  0.019348 | 0.012811 |   0.000374  |   -0.00951   |  manhattan  |    98   | uniform  |  0.491269  |
# |        500128-ELECTROSTEEL CASTINGS LTD.        |     ForwardSelection      |  0.031749 | 0.022861 |   0.001008  |  -0.007293   |  manhattan  |    96   | uniform  |  0.476886  |
# |        500128-ELECTROSTEEL CASTINGS LTD.        |    BackwardElimination    |  0.031862 | 0.022952 |   0.001015  |  -0.014477   |  euclidean  |    77   | uniform  |  0.481752  |
# |        500128-ELECTROSTEEL CASTINGS LTD.        | AllFeaturesConsideration  |  0.031842 | 0.022941 |   0.001014  |  -0.013157   |  euclidean  |   105   | uniform  |  0.46472   |
# |              500133-ESAB INDIA LTD.             |     ForwardSelection      |  0.031833 | 0.016554 |   0.001013  |  -0.008042   |  euclidean  |   105   | uniform  |  0.513143  |
# |              500133-ESAB INDIA LTD.             |    BackwardElimination    |  0.031747 | 0.01665  |   0.001008  |  -0.002611   |  euclidean  |    93   | uniform  |  0.474286  |
# |              500133-ESAB INDIA LTD.             | AllFeaturesConsideration  |  0.028997 | 0.016725 |   0.000841  |   0.163558   |  manhattan  |    85   | distance |  0.521143  |
# |                  500135-EPL Ltd                 |     ForwardSelection      |  0.027703 | 0.019442 |   0.000767  |  -0.009006   |  euclidean  |   105   | uniform  |  0.518391  |
# |                  500135-EPL Ltd                 |    BackwardElimination    |  0.027705 | 0.019574 |   0.000768  |  -0.009124   |  manhattan  |   105   | uniform  |  0.496552  |
# |                  500135-EPL Ltd                 | AllFeaturesConsideration  |  0.027741 | 0.019588 |   0.00077   |  -0.011728   |  manhattan  |    91   | uniform  |  0.498851  |
# |           500136-ESTER INDUSTRIES LTD.          |     ForwardSelection      |  0.036068 | 0.026484 |   0.001301  |   -0.00357   |  manhattan  |   105   | uniform  |  0.489308  |
# |           500136-ESTER INDUSTRIES LTD.          |    BackwardElimination    |  0.036068 | 0.026484 |   0.001301  |   -0.00357   |  manhattan  |   105   | uniform  |  0.489308  |
# |           500136-ESTER INDUSTRIES LTD.          | AllFeaturesConsideration  |  0.036151 | 0.026515 |   0.001307  |  -0.008208   |  euclidean  |    88   | uniform  |  0.483019  |
# |            500144-FINOLEX CABLES LTD.           |     ForwardSelection      |  0.023512 | 0.016876 |   0.000553  |  -0.001126   |  euclidean  |   105   | uniform  |  0.51986   |
# |            500144-FINOLEX CABLES LTD.           |    BackwardElimination    |  0.023512 | 0.016876 |   0.000553  |  -0.001126   |  euclidean  |   105   | uniform  |  0.51986   |
# |            500144-FINOLEX CABLES LTD.           | AllFeaturesConsideration  |  0.023541 | 0.01701  |   0.000554  |  -0.003638   |  manhattan  |    87   | distance |  0.488318  |
# |        500147-John Cockerill India Ltd-$        |     ForwardSelection      |  0.452132 | 0.038808 |   0.204423  |  -0.001392   |  euclidean  |    96   | uniform  |  0.484663  |
# |        500147-John Cockerill India Ltd-$        |    BackwardElimination    |  0.452113 | 0.038675 |   0.204406  |  -0.001309   |  euclidean  |    96   | uniform  |  0.534969  |
# |        500147-John Cockerill India Ltd-$        | AllFeaturesConsideration  |  0.452091 | 0.038839 |   0.204386  |  -0.001211   |  manhattan  |    91   | uniform  |  0.489571  |
# |                500148-UFLEX LTD.                |     ForwardSelection      |  0.030166 | 0.020664 |   0.00091   |   0.012833   |  manhattan  |   105   | uniform  |  0.534884  |
# |                500148-UFLEX LTD.                |    BackwardElimination    |  0.030217 | 0.020688 |   0.000913  |   0.009456   |  manhattan  |   105   | uniform  |  0.516796  |
# |                500148-UFLEX LTD.                | AllFeaturesConsideration  |  0.030417 | 0.02092  |   0.000925  |  -0.003692   |  euclidean  |    96   | uniform  |  0.50646   |
# |          500153-GANESH BENZOPLAST LTD.          | AllFeaturesConsideration  |  0.037635 | 0.027893 |   0.001416  |  -0.012754   |  manhattan  |    91   | distance |  0.49011   |
# |            500159-Metroglobal Limited           |     ForwardSelection      |  0.038387 | 0.029229 |   0.001474  |   0.019777   |  euclidean  |   105   | uniform  |  0.538298  |
# |            500159-Metroglobal Limited           |    BackwardElimination    |  0.03722  | 0.028222 |   0.001385  |   0.078473   |  euclidean  |    80   | distance |  0.56383   |
# |                 500171-GHCL LTD.                |    BackwardElimination    |  0.029175 | 0.018893 |   0.000851  |   0.009074   |  euclidean  |   103   | uniform  |  0.494869  |
# |                 500171-GHCL LTD.                | AllFeaturesConsideration  |  0.02947  | 0.019094 |   0.000868  |  -0.011031   |  euclidean  |   105   | uniform  |  0.496009  |
# |                  500173-GFL Ltd                 |     ForwardSelection      |  0.025567 | 0.01833  |   0.000654  |  -0.026036   |  manhattan  |   103   | uniform  |  0.492308  |
# |                  500173-GFL Ltd                 |    BackwardElimination    |  0.025534 | 0.018376 |   0.000652  |   -0.02338   |  manhattan  |   100   | uniform  |  0.470513  |
# |                  500173-GFL Ltd                 | AllFeaturesConsideration  |  0.025241 | 0.018038 |   0.000637  |   -9.1e-05   |  manhattan  |    96   | uniform  |  0.520513  |
# |           500179-HCL INFOSYSTEMS LTD.           |     ForwardSelection      |  0.031041 | 0.021589 |   0.000964  |  -0.002169   |  euclidean  |   105   | uniform  |  0.541096  |
# |           500179-HCL INFOSYSTEMS LTD.           |    BackwardElimination    |  0.031138 | 0.021626 |   0.00097   |  -0.008444   |  manhattan  |    97   | uniform  |  0.528539  |
# |           500179-HCL INFOSYSTEMS LTD.           | AllFeaturesConsideration  |  0.031225 | 0.021653 |   0.000975  |  -0.014131   |  manhattan  |   104   | uniform  |  0.510274  |
# |               500180-HDFC Bank Ltd              |     ForwardSelection      |  0.033736 | 0.013441 |   0.001138  |   0.005724   |  euclidean  |   104   | uniform  |  0.526198  |
# |               500180-HDFC Bank Ltd              |    BackwardElimination    |  0.033716 | 0.013382 |   0.001137  |   0.006896   |  manhattan  |   105   | uniform  |  0.548495  |
# |               500180-HDFC Bank Ltd              | AllFeaturesConsideration  |  0.033799 | 0.013469 |   0.001142  |   0.002006   |  manhattan  |   100   | uniform  |  0.510591  |
# |            500182-HERO MOTOCORP LTD.            |     ForwardSelection      |  0.019615 | 0.013737 |   0.000385  |   0.001199   |  manhattan  |    98   | uniform  |  0.523333  |
# |            500182-HERO MOTOCORP LTD.            |    BackwardElimination    |  0.019615 | 0.013737 |   0.000385  |   0.001199   |  manhattan  |    98   | uniform  |  0.523333  |
# |            500182-HERO MOTOCORP LTD.            | AllFeaturesConsideration  |  0.019721 | 0.013868 |   0.000389  |  -0.009685   |  manhattan  |    74   | uniform  |  0.493333  |
# |                 500183-HFCL Ltd                 |     ForwardSelection      |  0.033137 | 0.022694 |   0.001098  |  -0.004819   |  manhattan  |    92   | uniform  |  0.502455  |
# |                 500183-HFCL Ltd                 |    BackwardElimination    |  0.033326 | 0.022805 |   0.001111  |  -0.016288   |  manhattan  |    96   | uniform  |  0.479542  |
# |                 500183-HFCL Ltd                 | AllFeaturesConsideration  |  0.033168 | 0.022759 |    0.0011   |  -0.006669   |  manhattan  |   100   | uniform  |  0.482815  |
# |      500184-Himadri Speciality Chemical Ltd     |     ForwardSelection      |  0.035099 | 0.024983 |   0.001232  |   0.008486   |  euclidean  |   104   | distance |  0.524306  |
# |      500184-Himadri Speciality Chemical Ltd     |    BackwardElimination    |  0.035122 | 0.025024 |   0.001234  |   0.007207   |  euclidean  |    94   | distance |  0.517361  |
# |      500184-Himadri Speciality Chemical Ltd     | AllFeaturesConsideration  |  0.035161 | 0.024984 |   0.001236  |   0.004989   |  manhattan  |   100   | uniform  |  0.493056  |
# |      500185-HINDUSTAN CONSTRUCTION CO.LTD.      |     ForwardSelection      |  0.038929 | 0.027077 |   0.001515  |  -0.013057   |  euclidean  |    91   | uniform  |  0.498258  |
# |      500185-HINDUSTAN CONSTRUCTION CO.LTD.      |    BackwardElimination    |  0.038825 | 0.026934 |   0.001507  |  -0.007665   |  manhattan  |   103   | uniform  |  0.506388  |
# |      500185-HINDUSTAN CONSTRUCTION CO.LTD.      | AllFeaturesConsideration  |  0.039007 | 0.027224 |   0.001522  |  -0.017116   |  manhattan  |   105   | uniform  |  0.473868  |
# |     500186-HINDUSTAN OIL EXPLORATION CO.LTD.    |     ForwardSelection      |  0.036391 | 0.026227 |   0.001324  |   0.001883   |  manhattan  |   105   | uniform  |  0.503121  |
# |     500186-HINDUSTAN OIL EXPLORATION CO.LTD.    |    BackwardElimination    |  0.036475 | 0.026231 |   0.00133   |  -0.002704   |  manhattan  |   104   | uniform  |  0.501873  |
# |     500186-HINDUSTAN OIL EXPLORATION CO.LTD.    | AllFeaturesConsideration  |  0.036701 | 0.026286 |   0.001347  |  -0.015177   |  manhattan  |    96   | uniform  |  0.50437   |
# |                 500187-HSIL LTD.                | AllFeaturesConsideration  |  0.02511  | 0.018542 |   0.000631  |   0.008708   |  manhattan  |   105   | distance |  0.527886  |
# |              500189-Nxtdigital Ltd              |     ForwardSelection      |  0.046155 | 0.019856 |   0.00213   |   0.000129   |  manhattan  |   104   | uniform  |  0.496158  |
# |              500189-Nxtdigital Ltd              |    BackwardElimination    |  0.046103 | 0.01971  |   0.002126  |   0.002388   |  manhattan  |   102   | uniform  |  0.517014  |
# |              500189-Nxtdigital Ltd              | AllFeaturesConsideration  |  0.046365 | 0.019667 |   0.00215   |  -0.008983   |  euclidean  |   104   | distance |  0.506037  |
# |                  500193-HLV Ltd                 |     ForwardSelection      |  0.030141 | 0.020125 |   0.000908  |  -0.008933   |  manhattan  |    69   | uniform  |  0.48811   |
# |                  500193-HLV Ltd                 |    BackwardElimination    |  0.029969 | 0.019835 |   0.000898  |   0.002544   |  manhattan  |   105   | uniform  |  0.523154  |
# |                  500193-HLV Ltd                 | AllFeaturesConsideration  |  0.030357 | 0.020278 |   0.000922  |  -0.023435   |  euclidean  |    98   | uniform  |  0.459324  |
# |          500199-I G PETROCHEMICALS LTD.         |     ForwardSelection      |  0.103214 | 0.03898  |   0.010653  |  -4.698873   |  manhattan  |   105   | uniform  |  0.477457  |
# |          500199-I G PETROCHEMICALS LTD.         |    BackwardElimination    |  0.103214 | 0.03898  |   0.010653  |  -4.698873   |  manhattan  |   105   | uniform  |  0.477457  |
# |          500199-I G PETROCHEMICALS LTD.         | AllFeaturesConsideration  |  0.052813 | 0.03621  |   0.002789  |  -0.492121   |  euclidean  |    2    | uniform  |  0.472832  |
# |            500201-INDIA GLYCOLS LTD.            |     ForwardSelection      |  0.029784 | 0.021469 |   0.000887  |   0.011328   |  manhattan  |    81   | uniform  |  0.527497  |
# |            500201-INDIA GLYCOLS LTD.            |    BackwardElimination    |  0.030309 | 0.021879 |   0.000919  |  -0.023789   |  euclidean  |    95   | distance |  0.480359  |
# |            500201-INDIA GLYCOLS LTD.            | AllFeaturesConsideration  |  0.030121 | 0.021534 |   0.000907  |  -0.011186   |  manhattan  |   104   | distance |  0.536476  |
# |     500207-INDO RAMA SYNTHETICS (INDIA) LTD.    |     ForwardSelection      |  0.032078 | 0.023239 |   0.001029  |  -0.008545   |  euclidean  |   103   | uniform  |  0.499422  |
# |     500207-INDO RAMA SYNTHETICS (INDIA) LTD.    |    BackwardElimination    |  0.032078 | 0.023239 |   0.001029  |  -0.008545   |  euclidean  |   103   | uniform  |  0.499422  |
# |     500207-INDO RAMA SYNTHETICS (INDIA) LTD.    | AllFeaturesConsideration  |  0.032643 | 0.023455 |   0.001066  |  -0.044411   |  euclidean  |   105   | distance |  0.494798  |
# |               500209-INFOSYS LTD.               |     ForwardSelection      |  0.019088 | 0.013018 |   0.000364  |  -0.019393   |  manhattan  |    74   | uniform  |  0.510567  |
# |               500209-INFOSYS LTD.               |    BackwardElimination    |  0.019135 | 0.01302  |   0.000366  |  -0.024487   |  manhattan  |   102   | distance |  0.487208  |
# |               500209-INFOSYS LTD.               | AllFeaturesConsideration  |  0.019101 | 0.013028 |   0.000365  |   -0.02084   |  manhattan  |   104   | uniform  |  0.508343  |
# |        500210-INGERSOLL-RAND (INDIA) LTD.       |     ForwardSelection      |  0.021559 | 0.014046 |   0.000465  |   0.012539   |  manhattan  |    95   | distance |  0.52901   |
# ...
# |         500268-MANALI PETROCHEMICAL LTD.        |    BackwardElimination    |  0.032276 | 0.022223 |   0.001042  |   -0.01849   |  manhattan  |    80   | distance |  0.49697   |
# |         500268-MANALI PETROCHEMICAL LTD.        | AllFeaturesConsideration  |  0.032099 | 0.022112 |   0.00103   |  -0.007349   |  manhattan  |   105   | uniform  |  0.495758  |
# |        500271-Max Financial Services Ltd        |     ForwardSelection      |  0.026335 | 0.01847  |   0.000694  |  -0.013631   |  euclidean  |    96   | uniform  |  0.503866  |
# |        500271-Max Financial Services Ltd        |    BackwardElimination    |  0.026197 | 0.018417 |   0.000686  |  -0.003031   |  euclidean  |    75   | uniform  |  0.514175  |
# |        500271-Max Financial Services Ltd        | AllFeaturesConsideration  |  0.026195 | 0.01838  |   0.000686  |  -0.002865   |  euclidean  |   102   | uniform  |  0.523196  |
# |           500279-MIRC ELECTRONICS LTD.          |     ForwardSelection      |  0.036769 | 0.025922 |   0.001352  |   0.008148   |  manhattan  |   103   | uniform  |  0.506509  |
# |           500279-MIRC ELECTRONICS LTD.          |    BackwardElimination    |  0.036769 | 0.025922 |   0.001352  |   0.008148   |  manhattan  |   103   | uniform  |  0.506509  |
# |           500279-MIRC ELECTRONICS LTD.          | AllFeaturesConsideration  |  0.036969 | 0.026008 |   0.001367  |  -0.002649   |  manhattan  |   105   | uniform  |  0.511243  |
# |             500280-CENTURY ENKA LTD.            |     ForwardSelection      |  0.027112 | 0.018326 |   0.000735  |   0.00421    |  manhattan  |   103   | uniform  |  0.552119  |
# |             500280-CENTURY ENKA LTD.            |    BackwardElimination    |  0.027212 | 0.018428 |   0.000741  |  -0.003161   |  manhattan  |   104   | uniform  |  0.508591  |
# |             500280-CENTURY ENKA LTD.            | AllFeaturesConsideration  |  0.027239 | 0.018434 |   0.000742  |  -0.005115   |  manhattan  |   103   | uniform  |  0.522337  |
# |         500325-RELIANCE INDUSTRIES LTD.         |     ForwardSelection      |  0.020895 | 0.014846 |   0.000437  |  -0.005608   |  euclidean  |   105   | uniform  |  0.501669  |
# |         500325-RELIANCE INDUSTRIES LTD.         |    BackwardElimination    |  0.020795 | 0.014744 |   0.000432  |   0.004027   |  euclidean  |    83   | uniform  |  0.532814  |
# |         500325-RELIANCE INDUSTRIES LTD.         | AllFeaturesConsideration  |  0.021025 | 0.01496  |   0.000442  |  -0.018113   |  manhattan  |    95   | uniform  |  0.480534  |
# |             500387-SHREE CEMENT LTD.            |    BackwardElimination    |  0.01921  | 0.014247 |   0.000369  |  -0.018049   |  manhattan  |    89   | uniform  |  0.511858  |
# |             500387-SHREE CEMENT LTD.            | AllFeaturesConsideration  |   0.0191  | 0.014245 |   0.000365  |  -0.006402   |  manhattan  |    76   | distance |  0.503953  |
# |                500680-PFIZER LTD.               |     ForwardSelection      |  0.017147 | 0.011807 |   0.000294  |  -0.002412   |  manhattan  |   105   | uniform  |  0.502273  |
# |                500680-PFIZER LTD.               |    BackwardElimination    |  0.017148 | 0.011816 |   0.000294  |  -0.002479   |  manhattan  |   104   | uniform  |  0.511364  |
# |                500680-PFIZER LTD.               | AllFeaturesConsideration  |  0.017209 | 0.011848 |   0.000296  |  -0.009638   |  manhattan  |   104   | uniform  |  0.507955  |
# |            500770-TATA CHEMICALS LTD.           |     ForwardSelection      |  0.023104 | 0.015438 |   0.000534  |  -0.029713   |  manhattan  |    70   | uniform  |  0.483133  |
# |            500770-TATA CHEMICALS LTD.           |    BackwardElimination    |  0.023082 | 0.01522  |   0.000533  |  -0.027793   |  manhattan  |   100   | uniform  |  0.531325  |
# |            500770-TATA CHEMICALS LTD.           | AllFeaturesConsideration  |  0.023145 | 0.015365 |   0.000536  |  -0.033433   |  euclidean  |    85   | uniform  |  0.496386  |
# |             500790-NESTLE INDIA LTD.            |     ForwardSelection      |  0.015493 | 0.010913 |   0.00024   |  -0.014189   |  euclidean  |   105   | uniform  |  0.46941   |
# |             500790-NESTLE INDIA LTD.            |    BackwardElimination    |  0.015511 | 0.010945 |   0.000241  |  -0.016548   |  manhattan  |    93   | uniform  |  0.490545  |
# |             500790-NESTLE INDIA LTD.            | AllFeaturesConsideration  |  0.015535 | 0.010895 |   0.000241  |  -0.019793   |  euclidean  |   105   | uniform  |  0.500556  |
# |        530965-INDIAN OIL CORPORATION LTD.       |    BackwardElimination    |  0.053548 | 0.01933  |   0.002867  |   0.088881   |  euclidean  |    10   | uniform  |  0.52514   |
# |        530965-INDIAN OIL CORPORATION LTD.       | AllFeaturesConsideration  |  0.056031 | 0.01881  |   0.003139  |   0.002429   |  euclidean  |   104   | uniform  |  0.499441  |
# |            532163-SAREGAMA INDIA LTD.           |    BackwardElimination    |  0.03639  | 0.02635  |   0.001324  |  -0.066583   |  euclidean  |    99   | uniform  |  0.495402  |
# |            532163-SAREGAMA INDIA LTD.           | AllFeaturesConsideration  |  0.049534 | 0.028616 |   0.002454  |  -0.976251   |  manhattan  |    18   | uniform  |  0.471264  |
# |              532174-ICICI BANK LTD.             |     ForwardSelection      |  0.137355 | 0.023123 |   0.018866  |  -0.002908   |  manhattan  |    94   | distance |  0.46882   |
# |              532174-ICICI BANK LTD.             |    BackwardElimination    |  0.137124 | 0.023071 |   0.018803  |   0.000467   |  manhattan  |    99   | distance |  0.516704  |
# |              532174-ICICI BANK LTD.             | AllFeaturesConsideration  |  0.137321 | 0.023119 |   0.018857  |  -0.002416   |  euclidean  |    88   | uniform  |  0.512249  |
# |           532210-CITY UNION BANK LTD.           |     ForwardSelection      |  0.023405 | 0.015733 |   0.000548  |  -0.015282   |  euclidean  |   103   | uniform  |  0.485023  |
# |           532210-CITY UNION BANK LTD.           |    BackwardElimination    |  0.023405 | 0.015733 |   0.000548  |  -0.015282   |  euclidean  |   103   | uniform  |  0.485023  |
# |           532210-CITY UNION BANK LTD.           | AllFeaturesConsideration  |  0.023356 | 0.015631 |   0.000546  |  -0.011095   |  euclidean  |   103   | uniform  |  0.501152  |
# |       532488-DIVI&#39;S LABORATORIES LTD.       |     ForwardSelection      |  0.025147 | 0.01621  |   0.000632  |   -0.10326   |  manhattan  |    96   | distance |  0.517007  |
# |       532488-DIVI&#39;S LABORATORIES LTD.       |    BackwardElimination    |  0.024221 | 0.015701 |   0.000587  |  -0.023456   |  manhattan  |    96   | distance |  0.531746  |
# |       532488-DIVI&#39;S LABORATORIES LTD.       | AllFeaturesConsideration  |  0.02487  | 0.016521 |   0.000618  |  -0.079025   |  manhattan  |   104   | uniform  |  0.482993  |
# |           532538-ULTRATECH CEMENT LTD.          |     ForwardSelection      |  0.020411 | 0.014225 |   0.000417  |  -0.025135   |  euclidean  |    91   | distance |  0.520578  |
# |           532538-ULTRATECH CEMENT LTD.          |    BackwardElimination    |  0.020411 | 0.014225 |   0.000417  |  -0.025135   |  euclidean  |    91   | distance |  0.520578  |
# |           532538-ULTRATECH CEMENT LTD.          | AllFeaturesConsideration  |  0.020328 | 0.014361 |   0.000413  |   -0.0168    |  euclidean  |   103   | uniform  |  0.491657  |
# |      532540-TATA CONSULTANCY SERVICES LTD.      |     ForwardSelection      |  0.053172 | 0.015805 |   0.002827  |  -0.003554   |  manhattan  |   100   | distance |  0.49399   |
# |      532540-TATA CONSULTANCY SERVICES LTD.      |    BackwardElimination    |  0.053142 | 0.01587  |   0.002824  |   -0.00244   |  manhattan  |    98   | uniform  |  0.486779  |
# |      532540-TATA CONSULTANCY SERVICES LTD.      | AllFeaturesConsideration  |  0.053327 | 0.015852 |   0.002844  |  -0.009404   |  manhattan  |    96   | distance |  0.515625  |
# |                 532689-PVR LTD.                 |     ForwardSelection      |  0.024336 | 0.017253 |   0.000592  |  -0.007572   |  manhattan  |    54   | uniform  |  0.49711   |
# |                 532689-PVR LTD.                 |    BackwardElimination    |  0.024336 | 0.017253 |   0.000592  |  -0.007572   |  manhattan  |    54   | uniform  |  0.49711   |
# |                 532689-PVR LTD.                 | AllFeaturesConsideration  |  0.024323 | 0.017135 |   0.000592  |  -0.006486   |  euclidean  |   103   | uniform  |  0.504335  |
# |             532706-INOX LEISURE LTD.            |     ForwardSelection      |  0.027608 | 0.019987 |   0.000762  |  -0.000241   |  manhattan  |   100   | uniform  |  0.472087  |
# |             532706-INOX LEISURE LTD.            |    BackwardElimination    |  0.027608 | 0.019987 |   0.000762  |  -0.000241   |  manhattan  |   100   | uniform  |  0.472087  |
# |             532706-INOX LEISURE LTD.            | AllFeaturesConsideration  |  0.027666 | 0.019903 |   0.000765  |  -0.004458   |  manhattan  |   100   | uniform  |  0.489078  |
# |         532899-KAVERI SEED COMPANY LTD.         |     ForwardSelection      |  0.144635 | 0.024903 |   0.020919  |  -0.004371   |  manhattan  |    99   | distance |  0.507712  |
# |         532899-KAVERI SEED COMPANY LTD.         |    BackwardElimination    |  0.144635 | 0.024903 |   0.020919  |  -0.004371   |  manhattan  |    99   | distance |  0.507712  |
# |         532899-KAVERI SEED COMPANY LTD.         | AllFeaturesConsideration  |  0.143579 | 0.024741 |   0.020615  |   0.010246   |  manhattan  |   105   | uniform  |  0.502571  |
# |          533155-Jubilant FoodWorks Ltd          |     ForwardSelection      |  0.031127 | 0.018572 |   0.000969  |   -4.7e-05   |  manhattan  |   105   | uniform  |  0.536517  |
# |          533155-Jubilant FoodWorks Ltd          |    BackwardElimination    |  0.031127 | 0.018572 |   0.000969  |   -4.7e-05   |  manhattan  |   105   | uniform  |  0.536517  |
# |          533155-Jubilant FoodWorks Ltd          | AllFeaturesConsideration  |  0.031287 | 0.018722 |   0.000979  |   -0.01033   |  euclidean  |   105   | uniform  |  0.481742  |
# |             533260-CAREER POINT LTD.            |     ForwardSelection      |  0.047894 | 0.029455 |   0.002294  |  -0.812117   |  euclidean  |   105   | uniform  |  0.513219  |
# |             533260-CAREER POINT LTD.            |    BackwardElimination    |  0.036427 | 0.022307 |   0.001327  |  -0.048264   |  manhattan  |    51   | distance |  0.503888  |
# |             533260-CAREER POINT LTD.            | AllFeaturesConsideration  |  0.038821 | 0.023678 |   0.001507  |  -0.190612   |  euclidean  |   105   | uniform  |  0.496112  |
# |              533287-ZEE LEARN LTD.              |     ForwardSelection      |  0.027492 | 0.018234 |   0.000756  |  -0.012207   |  manhattan  |   100   | uniform  |  0.488818  |
# |              533287-ZEE LEARN LTD.              |    BackwardElimination    |  0.027492 | 0.018234 |   0.000756  |  -0.012207   |  manhattan  |   100   | uniform  |  0.488818  |
# |              533287-ZEE LEARN LTD.              | AllFeaturesConsideration  |  0.02759  | 0.018252 |   0.000761  |  -0.019412   |  manhattan  |   104   | uniform  |    0.5     |
# |        537291-Nath Bio-Genes (India) Ltd        |     ForwardSelection      |  0.033042 | 0.024029 |   0.001092  |  -0.000424   |  manhattan  |    86   | uniform  |  0.485849  |
# |        537291-Nath Bio-Genes (India) Ltd        |    BackwardElimination    |  0.032949 | 0.024023 |   0.001086  |   0.005183   |  euclidean  |    45   | uniform  |  0.509434  |
# |        537291-Nath Bio-Genes (India) Ltd        | AllFeaturesConsideration  |  0.033373 | 0.024279 |   0.001114  |  -0.020553   |  euclidean  |    94   | uniform  |  0.464623  |
# |    539921-Shanti Educational Initiatives Ltd    |     ForwardSelection      |  0.022079 | 0.012643 |   0.000487  |  -0.004417   |  manhattan  |    45   | distance |  0.632479  |
# |    539921-Shanti Educational Initiatives Ltd    |    BackwardElimination    |  0.021598 | 0.011551 |   0.000466  |   0.038876   |  manhattan  |    88   | distance |  0.683761  |
# |    539921-Shanti Educational Initiatives Ltd    | AllFeaturesConsideration  |  0.022222 | 0.011462 |   0.000494  |   -0.01745   |  euclidean  |    22   | distance |  0.666667  |
# |         542602-Embassy Office Parks REIT        |     ForwardSelection      |   0.0201  | 0.014369 |   0.000404  |  -0.033543   |  euclidean  |    56   | uniform  |  0.438462  |
# |         542602-Embassy Office Parks REIT        |    BackwardElimination    |   0.0201  | 0.014369 |   0.000404  |  -0.033543   |  euclidean  |    56   | uniform  |  0.438462  |
# |         542602-Embassy Office Parks REIT        | AllFeaturesConsideration  |  0.019908 | 0.013566 |   0.000396  |  -0.013895   |  euclidean  |    94   | distance |  0.530769  |
# +-------------------------------------------------+---------------------------+-----------+----------+-------------+--------------+-------------+---------+----------+------------+

# %%
final_df
# Out:
#                               Company                   Model  \
# 0            500002-ABB India Limited       Linear Regression
# 1            500002-ABB India Limited        Ridge Regression
# 2            500002-ABB India Limited        Lasso Regression
# 3            500002-ABB India Limited  Elastic Net Regression
# 617          500002-ABB India Limited          KNN-Regression
# ..                                ...                     ...
# 613  542602-Embassy Office Parks REIT        Lasso Regression
# 614  542602-Embassy Office Parks REIT  Elastic Net Regression
# 615  542602-Embassy Office Parks REIT       Linear Regression
# 616  542602-Embassy Office Parks REIT        Ridge Regression
# 770  542602-Embassy Office Parks REIT          KNN-Regression
#
#                                           Method  Percentage
# 0                                LinearFIFValue1    0.541713
# 1                                 RidgeFIFValue1    0.540601
# 2                                 LassoFIFValue1    0.537264
# 3                               ElasticFIFValue1    0.536151
# 617          KNN_Regression_FI_ForwardSelection_    0.517241
# ..                                           ...         ...
# 613                             LassoFIPValue0.1    0.569231
# 614                           ElasticFIPValue0.1    0.569231
# 615                      LinearFICoefficients0.1    0.538462
# 616                       RidgeFICoefficients0.1    0.538462
# 770  KNN_Regression_FI_AllFeaturesConsideration_    0.530769
#
# [771 rows x 4 columns]
