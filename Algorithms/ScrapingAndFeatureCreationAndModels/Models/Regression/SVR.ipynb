# %%
# %pip install seaborn

# %%
import csv
import numpy as np
import pandas as pd
import glob, os
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from datetime import *
from sklearn.svm import SVR
from sklearn import svm
from sklearn.metrics import mean_absolute_error,mean_squared_error
import seaborn as sns
from sklearn.model_selection import GridSearchCV
import warnings; warnings.simplefilter('ignore')
from sklearn.metrics import r2_score
from sklearn.metrics import median_absolute_error
from sklearn.metrics import explained_variance_score

from prettytable import PrettyTable

from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import f_regression
import statsmodels.api as sm

# %%
path = os.getcwd()
path
# Out:
# 'C:\\Users\\venu\\Desktop\\Stock Market Analysis'

# %% [markdown]
# # Pre-processing the Data

# %%
def pre_process_data(data,null_threshold):
    data.drop(columns=['Unix Date','Date'],axis=1,inplace=True)
    total = data.shape[0]
    for col in data.columns:
        if ((null_threshold * total / 100) < data[col].isnull().sum()):
            data.drop(columns=[col],axis=1,inplace=True)
    data.replace([np.inf, -np.inf], np.nan, inplace=True)
    data.dropna(axis=0,inplace=True)
    return data

# %% [markdown]
# # Removing columns based on the dependent column

# %%
def dependent_column(data,column):
    cols = [col for col in data.columns if ("next" not in col.lower() and col.lower().endswith("gr"))]
    cols.append(column)
    data = data[cols]
    return (data,column)

# %%
def forward_selection(data, target, significance_level=0.05):
    initial_features = data.columns.tolist()
    best_features = []
    while (len(initial_features)>0):
        remaining_features = list(set(initial_features)-set(best_features))
        new_pval = pd.Series(index=remaining_features)
        for new_column in remaining_features:
            model = sm.OLS(target, sm.add_constant(data[best_features+[new_column]]).astype(float)).fit()
            new_pval[new_column] = model.pvalues[new_column]
        min_p_value = new_pval.min()
        if(min_p_value<significance_level):
            best_features.append(new_pval.idxmin())
        else:
            break
    return best_features

# %%
def backward_elimination(data, target,significance_level = 0.05):
    features = data.columns.tolist()
    while(len(features)>0):
        features_with_constant = sm.add_constant(data[features]).astype(float)
        p_values = sm.OLS(target, features_with_constant).fit().pvalues[1:]
        max_p_value = p_values.max()
        if(max_p_value >= significance_level):
            excluded_feature = p_values.idxmax()
            features.remove(excluded_feature)
        else:
            break 
    return features

# %% [markdown]
# # ---

# %%
def Model(dataset,y):
    X = dataset.loc[:, dataset.columns != y]
    Y = dataset.loc[:, dataset.columns == y]
    count = 3
    step = 1000
    start = 1
    end = 10000
    while(count >= 0):
#         print("start  ------> " + str(start))
#         print("end    ------> " + str(end))
#         print("step   ------> " + str(step))
        best,step = bestParameters(start,end,step,X,Y)
        for key in best:
            if key == 'C':
                c = best[key]
                print(c)
        if(count == 3):
            start = c - 1000
            end = c + 1000
        if(count == 2):
            start = c - 100
            end = c + 100
        if(count == 1):
            start = c - 10
            end = c + 10
        step = step/10
        count = count - 1 
#         print("count : " , count)
    return c

# %%
def bestParameters(start,end,step,X,Y):
    parameters = {'kernel': ['rbf'], 'C': np.arange(start,end,step),  
              'gamma': [0.0001],'epsilon':[0.01]}
#     print("parameters ", parameters)
    svr = svm.SVR(gamma = 'auto')
    clf = GridSearchCV(svr, parameters, scoring = 'neg_mean_squared_error')
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
    clf.fit(X_train,y_train)
    best = clf.best_params_
#     print("best ", best)
    return (best,step)

# %% [markdown]
# # Finding results from each set of important features

# %%
columns = ['Company','Method','Percentage', 'r^2_score', 'Mean_SE', 'Mean_AE', 'Median_AE','EVS']

# %%
companies = {"500112" : "SBIN" ,
"500325" : "RELIANCE INDUSTRIES LTD",
"532540" : "TATA CONSULTANCY SERVICES LTD" ,
"500209" : "INFOSYS LTD", 
"532174" : "ICICI BANK LTD", 
"507685" : "WIPRO LTD", 
"530965" : "INDIAN OIL CORPORATION LTD", 
"500182" : "HERO MOTOCORP LTD", 
"532210" : "CITY UNION BANK LTD", 
"500180" : "HDFC Bank Ltd",
"500680" : "PFIZER LTD", 
"506395" : "COROMANDEL iNTERNATIONAL LTD",
"500770" : "TATA CHEMICALS LTD", 
"500085" : "CHAMBAL FERTILISERS & CHEMICALS LTD", 
"501425" : "BOMBAY BURMAH TRADING CORP.LTD", 
"532899" : "KAVERI SEED COMPANY LTD", 
"537291" : "NATH BIO-GENES (INDIA) LTD", 
"500790" : "NESTLE INDIA LTD", 
"500825" : "BRITANNIA INDUSTRIES LTD", 
"533155" : "JUBILANT FOODWORKS LTD", 
"533287" : "ZEE LEARN LTD", 
"533260" : "CAREER POINT LTD", 
"539921" : "SHANTI EDUCATIONAL INITIATIVES LTD", 
"542602" : "EMBASSY OFFICE PARKS REIT", 
"543217" : "MINDSPACE BUSINESS PARKS REIT", 
"543261" : "BROOKFIELD INDIA REAL ESTATE TRUST REIT", 
"532538" : "ULTRATECH CEMENT LTD", 
"500387" : "SHREE CEMENT LTD", 
"500425" : "AMBUJA CEMENTS LTD", 
"532689" : "PVR LTD", 
"532706" : "INOX LEISURE LTD", 
"532163" : "SAREGAMA INDIA LTD", 
"524715" : "SUN PHARMACEUTICAL INDUSTRIES LTD", 
"532488" : "DIVI'S LABORATORIES LTD",
"500124" : "DR.REDDY'S LABORATORIES LTD"}

# %%
models = ["SVR"]
tables = {model:PrettyTable() for model in models}
for name,table in tables.items():
    table.field_names = columns

# %%
final_df = pd.read_csv("C:\\Users\\venu\\Desktop\\Stock Market Analysis\\Data\\Models_Results\\df_Final_Results.csv")
final_df.drop('Unnamed: 0', inplace = True, axis = 'columns')
final_df
# Out:
#                                         Company                   Model  \
# 0    500085-CHAMBAL FERTILISERS & CHEMICALS LTD        Ridge Regression
# 1    500085-CHAMBAL FERTILISERS & CHEMICALS LTD       Linear Regression
# 2    500085-CHAMBAL FERTILISERS & CHEMICALS LTD        Lasso Regression
# 3    500085-CHAMBAL FERTILISERS & CHEMICALS LTD  Elastic Net Regression
# 4                                   500112-SBIN       Linear Regression
# ..                                          ...                     ...
# 123   539921-SHANTI EDUCATIONAL INITIATIVES LTD        Lasso Regression
# 124            542602-EMBASSY OFFICE PARKS REIT        Lasso Regression
# 125            542602-EMBASSY OFFICE PARKS REIT  Elastic Net Regression
# 126            542602-EMBASSY OFFICE PARKS REIT       Linear Regression
# 127            542602-EMBASSY OFFICE PARKS REIT        Ridge Regression
#
#                           Method  Percentage
# 0                 RidgeFIFValue1    0.506112
# 1    LinearFIBackwardElimination    0.501222
# 2                LassoFIFValue10    0.497555
# 3              ElasticFIFValue10    0.497555
# 4             LinearFIPValue0.05    0.528953
# ..                           ...         ...
# 123              LassoFIFValue10    0.495726
# 124             LassoFIPValue0.1    0.569231
# 125           ElasticFIPValue0.1    0.569231
# 126      LinearFICoefficients0.1    0.538462
# 127       RidgeFICoefficients0.1    0.538462
#
# [128 rows x 4 columns]

# %%
final_df.columns
# Out:
# Index(['Company', 'Model', 'Method', 'Percentage'], dtype='object')

# %%
def create_pretty_table(name, model, result, method, percentage):
    values = [name[2 : 8 ] + "-" + companies[name[2 : 8]], method, round(percentage, 6)] + [round(v, 6) for k,v in result.items() if not isinstance(v,dict)]
    tables[model].add_row(values)
    tables[model].title = model

# %%
def fit_SVR(df, column, method, value, name, results):
    print("SVR Model fitted using columns obtained from feature importance using " + method + " : ")
    c = Model(df, column)
#     print(c)
    X = df.loc[:, df.columns != column]
    Y = df.loc[:, df.columns == column]
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
    svr_rbf = SVR(kernel='rbf', C = 144, gamma = 0.0001, epsilon = 0.01)
    y_rbf = svr_rbf.fit(X_train, y_train).predict(X_test)
    
    y_rbf = y_rbf.astype(float)
    y_test = y_test[column]

    pred_actual = pd.DataFrame(list(zip(y_rbf, y_test)), 
                   columns =['Predicted Values', 'Actual Values'])
    pred_actual.to_csv("C:\\Users\\venu\\Desktop\\Stock Market Analysis\\Data\Models_Results\\" + name[2:8] + "_SVR_" + "FI_" + method + "_" + str(value) + ".csv" , index=False)
    
    same_dir = 0
    diff_dir = 0
    for a, b in zip(y_rbf, y_test) :
        if (a > 0 and b > 0) or (a < 0 and b < 0):
            same_dir += 1
        else:
            diff_dir += 1
    percentage = (same_dir / (same_dir + diff_dir))
    print("Values in Same direction -----> ----->", same_dir)
    print("Values in Opposite direction <----- -----> ", diff_dir)
    print("Percentage of correct direction : ", percentage)
    results["SVR_FI_" + method + "_" + str(value)] = percentage
    
    r = r2_score(y_test, y_rbf)
    mse = mean_squared_error(y_test, y_rbf)
    mae = mean_absolute_error(y_test, y_rbf)
    med = median_absolute_error(y_test, y_rbf)
    var = explained_variance_score(y_test, y_rbf)
    
    model_result = {'r' : r, "mse" : mse, "mae" : mae, 'med_ae' : med, 'evs' : var}
    
    create_pretty_table(name , "SVR", model_result, method + " " + value, percentage)

# %%
def get_results_from_FI_Coeffiecients(df, name, column, results):
    print("Features Importance using Coefficients")
    print("*****************************************************************************************")
    X = df[df.columns[:-1]]
    Y = df[column].values
    model_linear = LinearRegression(fit_intercept=True)
    model_linear.fit(X, Y)
    col_coef = list(df.columns)
    res_coef = [round(i,6) for i in list(model_linear.coef_)]
    rc_coef = list(zip(col_coef, res_coef))
    coef_features = []
    coef = [0.1]
    method = "Coefficients"
    for cf in coef:
        for i in range(len(rc_coef)):
            if ((abs(rc_coef[i][1])) > cf):
                coef_features.append(rc_coef[i][0])
        print("Features obtained from coefficients greater than " + str(cf) + " : ")
        print("--------------------------------------")
        print(coef_features)
        if (len(coef_features) == 0):
            continue
        coef_features.append(column)
        df_fic = df[coef_features]
        fit_SVR(df_fic, column, method, str(cf), name, results)
    print("*****************************************************************************************")

# %%
def get_results_from_FI_PValue(df, name, column, results):
    print("Features Importance using p-value")
    print("*****************************************************************************************")
    X = df[df.columns[:-1]]
    Y = df[column].values
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=0)
    X_train = np.array(X_train, dtype=float)
    ols_model = sm.OLS(Y_train, X_train).fit()
    col_pval = list(df.columns)
    pvals = list(ols_model.pvalues)
    pvals_cols = list(zip(col_pval, pvals))
    p = [0.02, 0.05, 0.1, 0.2]
    method = "PValue"
    for pv in p:
        pval_features = []
        for i in range(len(pvals_cols)):
            if (pvals_cols[i][1] < pv):
                pval_features.append(pvals_cols[i][0])
        print("Features obtained from p-values less than " + str(pv) + " : ")
        print("-------------------------------------------------")
        print(pval_features)
        if (len(pval_features) == 0):
            continue
        pval_features.append(column)
        df_fip = df[pval_features]
        fit_SVR(df_fip, column, method, str(pv), name, results)
    print("*****************************************************************************************")

# %%
def get_results_from_FI_FValues(df, name, column, results):
    print("Features Importance using f-value")
    print("*****************************************************************************************")
    X = df[df.columns[:-1]]
    Y = df[column].values
    fval_cols = X.columns
    freg_res = f_regression(X, Y)
#     print(freg_res[0])
    fvals = freg_res[0]
    fc = list(zip(fval_cols, fvals))
    f = [1, 10, 100, 1000]
    method = "FValue"
    for fv in f :
        fval_features = []
        for i in range(len(fc)):
            if ((abs(fc[i][1])) > fv):
                fval_features.append(fc[i][0])
        print("Features obtained from f-values greater than " + str(fv) + " : ")
        print("--------------------------------------")
        print(fval_features)
        if (len(fval_features) == 0):
            continue
        fval_features.append(column)
        df_fif = df[fval_features]
        fit_SVR(df_fif, column, method, str(fv), name, results)
    print("*****************************************************************************************")

# %%
def get_results_from_FI_ForwardSelection(df1, name, column, results):
    print("Features Importance using Forward Selection Method")
    print("*****************************************************************************************")
    method = "ForwardSelection"
    X = df1[df1.columns[:-1]]
    Y = df1[column].values
    forward_features = forward_selection(X,Y)
    print("Features obtained from Forward Selection method : ") 
    print("--------------------------------------")
    print(forward_features)
    if (len(forward_features) != 0):
        forward_features.append(column)
        df_fs = df1[forward_features]
        fit_SVR(df_fs, column, method, '', name, results)
    print("*****************************************************************************************")

# %%
def get_results_from_FI_BackwardElimination(df1, name, column, results):
    print("Features Importance using Backward Elimination Method")
    print("*****************************************************************************************")
    method = "BackwardElimination"
    X = df1[df1.columns[:-1]]
    Y = df1[column].values
    backward_features = backward_elimination(X,Y)
    print("Features obtained from Backward Elimination method : ") 
    print("--------------------------------------")
    print(backward_features)
    if (len(backward_features) != 0):
        backward_features.append(column)
        df_be = df1[backward_features]
        fit_SVR(df_be, column, method, '', name, results)
    print("*****************************************************************************************")

# %%
def get_results_from_each_set(data, name, final_df):
    df = pre_process_data(data, 60)
    column = "Next Day Close Price GR"
    (df1, column) = dependent_column(df, column)
    results = {}
    get_results_from_FI_Coeffiecients(df1, name, column, results)
    get_results_from_FI_PValue(df1, name, column, results)
    get_results_from_FI_ForwardSelection(df1, name, column, results)
    get_results_from_FI_BackwardElimination(df1, name, column, results)
    get_results_from_FI_FValues(df1, name, column, results)

    sorted_results = sorted(results.items(), key=lambda item: item[1])
    max_row = {'Company' : name[2 : 8] + "-" + companies[name[2 : 8]], 'Model' : 'SVR', 'Method' : sorted_results[-1][0], 'Percentage' : sorted_results[-1][1]}
    final_df = final_df.append(max_row, ignore_index = True)
    print("Maximum correct direction values are obtained for {} with a percentage of {}.".format(sorted_results[-1][0], sorted_results[-1][1]))
    return final_df

# %%
# %%time
for filename in os.listdir(os.path.join(path,"Data/Stock")):
    if filename.startswith("gr"):
        df_svr = pd.read_csv(os.path.join(path,"Data\Stock\\" + filename))
        name = os.path.join(path, "Data\Stock\\" + filename).split("\\")[-1]
        stock = name[2 : 8]
        fd_df = pd.DataFrame(columns = final_df.columns)
        print("For stock : ", stock)
        print("#################################################################################################################")
        f_df = get_results_from_each_set(df_svr, name, fd_df)
        final_df = final_df.append(f_df, ignore_index = True)
        print("#################################################################################################################")

final_df = final_df.sort_values(by = ['Company', 'Percentage'], ascending = [True, False])
final_df.to_csv('C:\\Users\\venu\\Desktop\\Stock Market Analysis\\Data\\Models_Results\\df_Final_Results.csv')
# Out:
# For stock :  500085
# #################################################################################################################
# Features Importance using Coefficients
# *****************************************************************************************
# Features obtained from coefficients greater than 0.1 :
# --------------------------------------
# []
# *****************************************************************************************
# Features Importance using p-value
# *****************************************************************************************
# Features obtained from p-values less than 0.02 :
# -------------------------------------------------
# []
# Features obtained from p-values less than 0.05 :
# -------------------------------------------------
# []
# Features obtained from p-values less than 0.1 :
# -------------------------------------------------
# []
# Features obtained from p-values less than 0.2 :
# -------------------------------------------------
# ['Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 9001
# 9701.0
# 9691.0
# 9691.0
# Values in Same direction -----> -----> 384
# Values in Opposite direction <----- ----->  434
# Percentage of correct direction :  0.46943765281173594
# *****************************************************************************************
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Beta GR']
# SVR Model fitted using columns obtained from feature importance using ForwardSelection :
# 1
# 1.0
# 11.0
# 13.0
# Values in Same direction -----> -----> 388
# Values in Opposite direction <----- ----->  430
# Percentage of correct direction :  0.4743276283618582
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['Beta GR']
# SVR Model fitted using columns obtained from feature importance using BackwardElimination :
# 1
# 1.0
# 11.0
# 13.0
# Values in Same direction -----> -----> 388
# Values in Opposite direction <----- ----->  430
# Percentage of correct direction :  0.4743276283618582
# *****************************************************************************************
# Features Importance using f-value
# *****************************************************************************************
# Features obtained from f-values greater than 1 :
# --------------------------------------
# ['Open Price GR', 'Low Price GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 405
# Values in Opposite direction <----- ----->  413
# Percentage of correct direction :  0.49511002444987773
# Features obtained from f-values greater than 10 :
# --------------------------------------
# ['Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 1.0
# 10.0
# Values in Same direction -----> -----> 394
# Values in Opposite direction <----- ----->  424
# Percentage of correct direction :  0.48166259168704156
# Features obtained from f-values greater than 100 :
# --------------------------------------
# []
# Features obtained from f-values greater than 1000 :
# --------------------------------------
# []
# *****************************************************************************************
# Maximum correct direction values are obtained for SVR_FI_FValue_1 with a percentage of 0.49511002444987773.
# #################################################################################################################
# For stock :  500112
# #################################################################################################################
# Features Importance using Coefficients
# *****************************************************************************************
# Features obtained from coefficients greater than 0.1 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'Total Turnover (Rs.) GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using Coefficients :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 434
# Values in Opposite direction <----- ----->  464
# Percentage of correct direction :  0.48329621380846327
# *****************************************************************************************
# Features Importance using p-value
# *****************************************************************************************
# Features obtained from p-values less than 0.02 :
# -------------------------------------------------
# ['Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 6001
# 6001.0
# 5911.0
# 5911.0
# Values in Same direction -----> -----> 435
# Values in Opposite direction <----- ----->  463
# Percentage of correct direction :  0.4844097995545657
# Features obtained from p-values less than 0.05 :
# -------------------------------------------------
# ['Open Price GR', 'No. of Trades GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 101.0
# 61.0
# 65.0
# Values in Same direction -----> -----> 452
# Values in Opposite direction <----- ----->  446
# Percentage of correct direction :  0.5033407572383074
# Features obtained from p-values less than 0.1 :
# -------------------------------------------------
# ['Open Price GR', 'No.of Shares GR', 'No. of Trades GR', 'Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 61.0
# 65.0
# Values in Same direction -----> -----> 445
# Values in Opposite direction <----- ----->  453
# Percentage of correct direction :  0.4955456570155902
# Features obtained from p-values less than 0.2 :
# -------------------------------------------------
# ['Open Price GR', 'High Price GR', 'Close Price GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Deliverable Quantity GR', '% Deli. Qty to Traded Qty GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 41.0
# 43.0
# Values in Same direction -----> -----> 442
# Values in Opposite direction <----- ----->  456
# Percentage of correct direction :  0.4922048997772829
# *****************************************************************************************
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Beta GR', 'Close Price GR', 'Spread High-Low GR', 'Low Price GR', 'High Price GR', 'Alpha GR', 'No.of Shares GR', 'Total Turnover (Rs.) GR', 'No. of Trades GR', 'WAP GR', 'Open Price GR']
# SVR Model fitted using columns obtained from feature importance using ForwardSelection :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 454
# Values in Opposite direction <----- ----->  444
# Percentage of correct direction :  0.5055679287305123
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['Open Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Spread High-Low GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using BackwardElimination :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 452
# Values in Opposite direction <----- ----->  446
# Percentage of correct direction :  0.5033407572383074
# *****************************************************************************************
# Features Importance using f-value
# *****************************************************************************************
# Features obtained from f-values greater than 1 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'Spread High-Low GR', 'Alpha GR', 'Beta GR', 'Revenue GR', 'Dividend Value GR', 'Income GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 41.0
# 39.0
# Values in Same direction -----> -----> 434
# Values in Opposite direction <----- ----->  464
# Percentage of correct direction :  0.48329621380846327
# Features obtained from f-values greater than 10 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'Spread High-Low GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 51.0
# 53.0
# Values in Same direction -----> -----> 435
# Values in Opposite direction <----- ----->  463
# Percentage of correct direction :  0.4844097995545657
# Features obtained from f-values greater than 100 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1001
# 401.0
# 331.0
# 339.0
# Values in Same direction -----> -----> 453
# Values in Opposite direction <----- ----->  445
# Percentage of correct direction :  0.5044543429844098
# Features obtained from f-values greater than 1000 :
# --------------------------------------
# ['Beta GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 7001
# 7101.0
# 7191.0
# 7191.0
# Values in Same direction -----> -----> 434
# Values in Opposite direction <----- ----->  464
# Percentage of correct direction :  0.48329621380846327
# *****************************************************************************************
# Maximum correct direction values are obtained for SVR_FI_ForwardSelection_ with a percentage of 0.5055679287305123.
# #################################################################################################################
# For stock :  500124
# #################################################################################################################
# Features Importance using Coefficients
# *****************************************************************************************
# Features obtained from coefficients greater than 0.1 :
# --------------------------------------
# ['WAP GR']
# SVR Model fitted using columns obtained from feature importance using Coefficients :
# 1001
# 401.0
# 431.0
# 429.0
# Values in Same direction -----> -----> 438
# Values in Opposite direction <----- ----->  444
# Percentage of correct direction :  0.4965986394557823
# *****************************************************************************************
# Features Importance using p-value
# *****************************************************************************************
# Features obtained from p-values less than 0.02 :
# -------------------------------------------------
# ['Close Price GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 3001
# 2901.0
# 2901.0
# 2902.0
# Values in Same direction -----> -----> 442
# Values in Opposite direction <----- ----->  440
# Percentage of correct direction :  0.5011337868480725
# Features obtained from p-values less than 0.05 :
# -------------------------------------------------
# ['Open Price GR', 'Close Price GR', 'WAP GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 4001
# 3901.0
# 3901.0
# 3900.0
# Values in Same direction -----> -----> 437
# Values in Opposite direction <----- ----->  445
# Percentage of correct direction :  0.4954648526077097
# Features obtained from p-values less than 0.1 :
# -------------------------------------------------
# ['Open Price GR', 'High Price GR', 'Close Price GR', 'WAP GR', '% Deli. Qty to Traded Qty GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 101.0
# 41.0
# 37.0
# Values in Same direction -----> -----> 427
# Values in Opposite direction <----- ----->  455
# Percentage of correct direction :  0.48412698412698413
# Features obtained from p-values less than 0.2 :
# -------------------------------------------------
# ['Open Price GR', 'High Price GR', 'Close Price GR', 'WAP GR', '% Deli. Qty to Traded Qty GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 1.0
# 3.0
# Values in Same direction -----> -----> 439
# Values in Opposite direction <----- ----->  443
# Percentage of correct direction :  0.4977324263038549
# *****************************************************************************************
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Low Price GR', '% Deli. Qty to Traded Qty GR']
# SVR Model fitted using columns obtained from feature importance using ForwardSelection :
# 4001
# 3701.0
# 3691.0
# 3691.0
# Values in Same direction -----> -----> 427
# Values in Opposite direction <----- ----->  455
# Percentage of correct direction :  0.48412698412698413
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['WAP GR', '% Deli. Qty to Traded Qty GR']
# SVR Model fitted using columns obtained from feature importance using BackwardElimination :
# 1
# 101.0
# 91.0
# 100.0
# Values in Same direction -----> -----> 427
# Values in Opposite direction <----- ----->  455
# Percentage of correct direction :  0.48412698412698413
# *****************************************************************************************
# Features Importance using f-value
# *****************************************************************************************
# Features obtained from f-values greater than 1 :
# --------------------------------------
# ['High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', '% Deli. Qty to Traded Qty GR', 'Spread High-Low GR', 'Spread Close-Open GR', 'Beta GR', 'Dividend Value GR', 'Net Profit GR', 'EPS GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 438
# Values in Opposite direction <----- ----->  444
# Percentage of correct direction :  0.4965986394557823
# Features obtained from f-values greater than 10 :
# --------------------------------------
# []
# Features obtained from f-values greater than 100 :
# --------------------------------------
# []
# Features obtained from f-values greater than 1000 :
# --------------------------------------
# []
# *****************************************************************************************
# Maximum correct direction values are obtained for SVR_FI_PValue_0.02 with a percentage of 0.5011337868480725.
# #################################################################################################################
# For stock :  500180
# #################################################################################################################
# Features Importance using Coefficients
# *****************************************************************************************
# Features obtained from coefficients greater than 0.1 :
# --------------------------------------
# ['Low Price GR', 'Close Price GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using Coefficients :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 483
# Values in Opposite direction <----- ----->  414
# Percentage of correct direction :  0.5384615384615384
# *****************************************************************************************
# Features Importance using p-value
# *****************************************************************************************
# Features obtained from p-values less than 0.02 :
# -------------------------------------------------
# ['Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 1.0
# 2.0
# Values in Same direction -----> -----> 485
# Values in Opposite direction <----- ----->  412
# Percentage of correct direction :  0.5406911928651059
# Features obtained from p-values less than 0.05 :
# -------------------------------------------------
# ['Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 1.0
# 2.0
# Values in Same direction -----> -----> 485
# Values in Opposite direction <----- ----->  412
# Percentage of correct direction :  0.5406911928651059
# Features obtained from p-values less than 0.1 :
# -------------------------------------------------
# ['Low Price GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 1.0
# 2.0
# Values in Same direction -----> -----> 473
# Values in Opposite direction <----- ----->  424
# Percentage of correct direction :  0.5273132664437012
# Features obtained from p-values less than 0.2 :
# -------------------------------------------------
# ['Open Price GR', 'Low Price GR', 'Close Price GR', 'Alpha GR', 'Beta GR', 'Revenue GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 474
# Values in Opposite direction <----- ----->  423
# Percentage of correct direction :  0.5284280936454849
# *****************************************************************************************
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Beta GR', 'Alpha GR', 'Spread Close-Open GR', 'Deliverable Quantity GR']
# SVR Model fitted using columns obtained from feature importance using ForwardSelection :
# 1
# 1.0
# 1.0
# 2.0
# Values in Same direction -----> -----> 455
# Values in Opposite direction <----- ----->  442
# Percentage of correct direction :  0.5072463768115942
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['Close Price GR', 'No.of Shares GR', 'No. of Trades GR', 'Total Turnover (Rs.) GR', 'Spread Close-Open GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using BackwardElimination :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 451
# Values in Opposite direction <----- ----->  446
# Percentage of correct direction :  0.5027870680044593
# *****************************************************************************************
# Features Importance using f-value
# *****************************************************************************************
# Features obtained from f-values greater than 1 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'Spread Close-Open GR', 'Alpha GR', 'Beta GR', 'Dividend Value GR', 'Expenditure GR', 'Net Profit GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 459
# Values in Opposite direction <----- ----->  438
# Percentage of correct direction :  0.5117056856187291
# Features obtained from f-values greater than 10 :
# --------------------------------------
# ['Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 1.0
# 2.0
# Values in Same direction -----> -----> 485
# Values in Opposite direction <----- ----->  412
# Percentage of correct direction :  0.5406911928651059
# Features obtained from f-values greater than 100 :
# --------------------------------------
# ['Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 1.0
# 2.0
# Values in Same direction -----> -----> 485
# Values in Opposite direction <----- ----->  412
# Percentage of correct direction :  0.5406911928651059
# Features obtained from f-values greater than 1000 :
# --------------------------------------
# ['Beta GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 485
# Values in Opposite direction <----- ----->  412
# Percentage of correct direction :  0.5406911928651059
# *****************************************************************************************
# Maximum correct direction values are obtained for SVR_FI_FValue_1000 with a percentage of 0.5406911928651059.
# #################################################################################################################
# For stock :  500182
# #################################################################################################################
# Features Importance using Coefficients
# *****************************************************************************************
# Features obtained from coefficients greater than 0.1 :
# --------------------------------------
# ['Net Profit GR', 'EPS GR']
# SVR Model fitted using columns obtained from feature importance using Coefficients :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 468
# Values in Opposite direction <----- ----->  432
# Percentage of correct direction :  0.52
# *****************************************************************************************
# Features Importance using p-value
# *****************************************************************************************
# Features obtained from p-values less than 0.02 :
# -------------------------------------------------
# ['No. of Trades GR', 'Deliverable Quantity GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 1.0
# 6.0
# Values in Same direction -----> -----> 449
# Values in Opposite direction <----- ----->  451
# Percentage of correct direction :  0.4988888888888889
# Features obtained from p-values less than 0.05 :
# -------------------------------------------------
# ['No. of Trades GR', 'Deliverable Quantity GR', 'Dividend Value GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 21.0
# 20.0
# Values in Same direction -----> -----> 452
# Values in Opposite direction <----- ----->  448
# Percentage of correct direction :  0.5022222222222222
# Features obtained from p-values less than 0.1 :
# -------------------------------------------------
# ['Close Price GR', 'No. of Trades GR', 'Deliverable Quantity GR', 'Dividend Value GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 11.0
# 11.0
# Values in Same direction -----> -----> 455
# Values in Opposite direction <----- ----->  445
# Percentage of correct direction :  0.5055555555555555
# Features obtained from p-values less than 0.2 :
# -------------------------------------------------
# ['High Price GR', 'Close Price GR', 'No. of Trades GR', 'Deliverable Quantity GR', 'Dividend Value GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 460
# Values in Opposite direction <----- ----->  440
# Percentage of correct direction :  0.5111111111111111
# *****************************************************************************************
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Net Profit GR', 'Alpha GR', 'No. of Trades GR']
# SVR Model fitted using columns obtained from feature importance using ForwardSelection :
# 1
# 1.0
# 1.0
# 2.0
# Values in Same direction -----> -----> 452
# Values in Opposite direction <----- ----->  448
# Percentage of correct direction :  0.5022222222222222
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['No. of Trades GR', 'Alpha GR', 'Net Profit GR']
# SVR Model fitted using columns obtained from feature importance using BackwardElimination :
# 1
# 1.0
# 1.0
# 2.0
# Values in Same direction -----> -----> 452
# Values in Opposite direction <----- ----->  448
# Percentage of correct direction :  0.5022222222222222
# *****************************************************************************************
# Features Importance using f-value
# *****************************************************************************************
# Features obtained from f-values greater than 1 :
# --------------------------------------
# ['Close Price GR', 'No. of Trades GR', 'Alpha GR', 'Beta GR', 'Revenue GR', 'Dividend Value GR', 'Expenditure GR', 'Net Profit GR', 'EPS GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 450
# Values in Opposite direction <----- ----->  450
# Percentage of correct direction :  0.5
# Features obtained from f-values greater than 10 :
# --------------------------------------
# ['Revenue GR', 'Net Profit GR', 'EPS GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 463
# Values in Opposite direction <----- ----->  437
# Percentage of correct direction :  0.5144444444444445
# Features obtained from f-values greater than 100 :
# --------------------------------------
# []
# Features obtained from f-values greater than 1000 :
# --------------------------------------
# []
# *****************************************************************************************
# Maximum correct direction values are obtained for SVR_FI_Coefficients_0.1 with a percentage of 0.52.
# #################################################################################################################
# For stock :  500209
# #################################################################################################################
# Features Importance using Coefficients
# *****************************************************************************************
# Features obtained from coefficients greater than 0.1 :
# --------------------------------------
# ['High Price GR', 'WAP GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using Coefficients :
# 1
# 1.0
# 41.0
# 41.0
# Values in Same direction -----> -----> 464
# Values in Opposite direction <----- ----->  435
# Percentage of correct direction :  0.5161290322580645
# *****************************************************************************************
# Features Importance using p-value
# *****************************************************************************************
# Features obtained from p-values less than 0.02 :
# -------------------------------------------------
# ['No.of Shares GR', 'Total Turnover (Rs.) GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 41.0
# 38.0
# Values in Same direction -----> -----> 435
# Values in Opposite direction <----- ----->  464
# Percentage of correct direction :  0.4838709677419355
# Features obtained from p-values less than 0.05 :
# -------------------------------------------------
# ['No.of Shares GR', 'Total Turnover (Rs.) GR', 'Alpha GR', 'Beta GR', 'Net Profit GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 41.0
# 40.0
# Values in Same direction -----> -----> 452
# Values in Opposite direction <----- ----->  447
# Percentage of correct direction :  0.5027808676307007
# Features obtained from p-values less than 0.1 :
# -------------------------------------------------
# ['No.of Shares GR', 'Total Turnover (Rs.) GR', 'Alpha GR', 'Beta GR', 'Net Profit GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 41.0
# 40.0
# Values in Same direction -----> -----> 452
# Values in Opposite direction <----- ----->  447
# Percentage of correct direction :  0.5027808676307007
# Features obtained from p-values less than 0.2 :
# -------------------------------------------------
# ['No.of Shares GR', 'Total Turnover (Rs.) GR', 'Alpha GR', 'Beta GR', 'Net Profit GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 41.0
# 40.0
# Values in Same direction -----> -----> 452
# Values in Opposite direction <----- ----->  447
# Percentage of correct direction :  0.5027808676307007
# *****************************************************************************************
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Beta GR', 'Alpha GR', 'WAP GR', 'No. of Trades GR', 'Spread High-Low GR', 'Net Profit GR']
# SVR Model fitted using columns obtained from feature importance using ForwardSelection :
# 1
# 1.0
# 41.0
# 39.0
# Values in Same direction -----> -----> 443
# Values in Opposite direction <----- ----->  456
# Percentage of correct direction :  0.492769744160178
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['High Price GR', 'WAP GR', 'No.of Shares GR', 'Total Turnover (Rs.) GR', 'Alpha GR', 'Beta GR', 'Net Profit GR']
# SVR Model fitted using columns obtained from feature importance using BackwardElimination :
# 1
# 1.0
# 41.0
# 41.0
# Values in Same direction -----> -----> 452
# Values in Opposite direction <----- ----->  447
# Percentage of correct direction :  0.5027808676307007
# *****************************************************************************************
# Features Importance using f-value
# *****************************************************************************************
# Features obtained from f-values greater than 1 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No. of Trades GR', 'Spread High-Low GR', 'Alpha GR', 'Beta GR', 'Net Profit GR', 'EPS GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 41.0
# 40.0
# Values in Same direction -----> -----> 466
# Values in Opposite direction <----- ----->  433
# Percentage of correct direction :  0.5183537263626251
# Features obtained from f-values greater than 10 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 41.0
# 36.0
# Values in Same direction -----> -----> 456
# Values in Opposite direction <----- ----->  443
# Percentage of correct direction :  0.5072302558398221
# Features obtained from f-values greater than 100 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 41.0
# 36.0
# Values in Same direction -----> -----> 456
# Values in Opposite direction <----- ----->  443
# Percentage of correct direction :  0.5072302558398221
# Features obtained from f-values greater than 1000 :
# --------------------------------------
# []
# *****************************************************************************************
# Maximum correct direction values are obtained for SVR_FI_FValue_1 with a percentage of 0.5183537263626251.
# #################################################################################################################
# For stock :  500325
# #################################################################################################################
# Features Importance using Coefficients
# *****************************************************************************************
# Features obtained from coefficients greater than 0.1 :
# --------------------------------------
# ['Low Price GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using Coefficients :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 435
# Values in Opposite direction <----- ----->  464
# Percentage of correct direction :  0.4838709677419355
# *****************************************************************************************
# Features Importance using p-value
# *****************************************************************************************
# Features obtained from p-values less than 0.02 :
# -------------------------------------------------
# ['Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 422
# Values in Opposite direction <----- ----->  477
# Percentage of correct direction :  0.4694104560622914
# Features obtained from p-values less than 0.05 :
# -------------------------------------------------
# ['Alpha GR', 'Beta GR', 'Revenue GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 432
# Values in Opposite direction <----- ----->  467
# Percentage of correct direction :  0.48053392658509453
# Features obtained from p-values less than 0.1 :
# -------------------------------------------------
# ['No. of Trades GR', 'Alpha GR', 'Beta GR', 'Revenue GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 1.0
# 2.0
# Values in Same direction -----> -----> 442
# Values in Opposite direction <----- ----->  457
# Percentage of correct direction :  0.4916573971078977
# Features obtained from p-values less than 0.2 :
# -------------------------------------------------
# ['No. of Trades GR', 'Alpha GR', 'Beta GR', 'Revenue GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 1.0
# 2.0
# Values in Same direction -----> -----> 442
# Values in Opposite direction <----- ----->  457
# Percentage of correct direction :  0.4916573971078977
# *****************************************************************************************
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Alpha GR', 'Beta GR', 'High Price GR']
# SVR Model fitted using columns obtained from feature importance using ForwardSelection :
# 1
# 1.0
# 1.0
# 2.0
# Values in Same direction -----> -----> 412
# Values in Opposite direction <----- ----->  487
# Percentage of correct direction :  0.4582869855394883
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['Close Price GR', 'Alpha GR', 'Beta GR', 'Revenue GR', 'EPS GR']
# SVR Model fitted using columns obtained from feature importance using BackwardElimination :
# 1
# 1.0
# 1.0
# 3.0
# Values in Same direction -----> -----> 447
# Values in Opposite direction <----- ----->  452
# Percentage of correct direction :  0.4972191323692992
# *****************************************************************************************
# Features Importance using f-value
# *****************************************************************************************
# Features obtained from f-values greater than 1 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'Spread High-Low GR', 'Alpha GR', 'Beta GR', 'Revenue GR', 'Net Profit GR', 'EPS GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 422
# Values in Opposite direction <----- ----->  477
# Percentage of correct direction :  0.4694104560622914
# Features obtained from f-values greater than 10 :
# --------------------------------------
# ['Open Price GR', 'High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 427
# Values in Opposite direction <----- ----->  472
# Percentage of correct direction :  0.474972191323693
# Features obtained from f-values greater than 100 :
# --------------------------------------
# ['Alpha GR', 'Beta GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 1.0
# 1.0
# Values in Same direction -----> -----> 422
# Values in Opposite direction <----- ----->  477
# Percentage of correct direction :  0.4694104560622914
# Features obtained from f-values greater than 1000 :
# --------------------------------------
# []
# *****************************************************************************************
# Maximum correct direction values are obtained for SVR_FI_BackwardElimination_ with a percentage of 0.4972191323692992.
# #################################################################################################################
# For stock :  500387
# #################################################################################################################
# Features Importance using Coefficients
# *****************************************************************************************
# Features obtained from coefficients greater than 0.1 :
# --------------------------------------
# ['Close Price GR', 'WAP GR', 'Net Profit GR', 'EPS GR']
# SVR Model fitted using columns obtained from feature importance using Coefficients :
# 9001
# 9301.0
# 9231.0
# 9231.0
# Values in Same direction -----> -----> 253
# Values in Opposite direction <----- ----->  253
# Percentage of correct direction :  0.5
# *****************************************************************************************
# Features Importance using p-value
# *****************************************************************************************
# Features obtained from p-values less than 0.02 :
# -------------------------------------------------
# ['Close Price GR', 'WAP GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 7001
# 6601.0
# 6591.0
# 6589.0
# Values in Same direction -----> -----> 248
# Values in Opposite direction <----- ----->  258
# Percentage of correct direction :  0.4901185770750988
# Features obtained from p-values less than 0.05 :
# -------------------------------------------------
# ['Close Price GR', 'WAP GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 7001
# 6601.0
# 6591.0
# 6589.0
# Values in Same direction -----> -----> 248
# Values in Opposite direction <----- ----->  258
# Percentage of correct direction :  0.4901185770750988
# Features obtained from p-values less than 0.1 :
# -------------------------------------------------
# ['Close Price GR', 'WAP GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 7001
# 6601.0
# 6591.0
# 6589.0
# Values in Same direction -----> -----> 248
# Values in Opposite direction <----- ----->  258
# Percentage of correct direction :  0.4901185770750988
# Features obtained from p-values less than 0.2 :
# -------------------------------------------------
# ['Low Price GR', 'Close Price GR', 'WAP GR', 'No.of Shares GR', 'Total Turnover (Rs.) GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 1
# 1.0
# 11.0
# 6.0
# Values in Same direction -----> -----> 245
# Values in Opposite direction <----- ----->  261
# Percentage of correct direction :  0.4841897233201581
# *****************************************************************************************
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# []
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['Close Price GR', 'WAP GR']
# SVR Model fitted using columns obtained from feature importance using BackwardElimination :
# 7001
# 6601.0
# 6591.0
# 6589.0
# Values in Same direction -----> -----> 248
# Values in Opposite direction <----- ----->  258
# Percentage of correct direction :  0.4901185770750988
# *****************************************************************************************
# Features Importance using f-value
# *****************************************************************************************
# Features obtained from f-values greater than 1 :
# --------------------------------------
# ['WAP GR', 'Alpha GR', 'Revenue GR', 'Income GR', 'Expenditure GR']
# SVR Model fitted using columns obtained from feature importance using FValue :
# 1
# 1.0
# 1.0
# 2.0
# Values in Same direction -----> -----> 251
# Values in Opposite direction <----- ----->  255
# Percentage of correct direction :  0.49604743083003955
# Features obtained from f-values greater than 10 :
# --------------------------------------
# []
# Features obtained from f-values greater than 100 :
# --------------------------------------
# []
# Features obtained from f-values greater than 1000 :
# --------------------------------------
# []
# *****************************************************************************************
# Maximum correct direction values are obtained for SVR_FI_Coefficients_0.1 with a percentage of 0.5.
# #################################################################################################################
# For stock :  500680
# #################################################################################################################
# Features Importance using Coefficients
# *****************************************************************************************
# Features obtained from coefficients greater than 0.1 :
# --------------------------------------
# ['Low Price GR', 'WAP GR']
# SVR Model fitted using columns obtained from feature importance using Coefficients :
# 5001
# 5301.0
# 5291.0
# 5296.0
# Values in Same direction -----> -----> 436
# Values in Opposite direction <----- ----->  444
# Percentage of correct direction :  0.4954545454545455
# *****************************************************************************************
# Features Importance using p-value
# *****************************************************************************************
# Features obtained from p-values less than 0.02 :
# -------------------------------------------------
# ['Low Price GR', 'Close Price GR', 'WAP GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 5001
# 4901.0
# 4901.0
# 4901.0
# Values in Same direction -----> -----> 421
# Values in Opposite direction <----- ----->  459
# Percentage of correct direction :  0.4784090909090909
# Features obtained from p-values less than 0.05 :
# -------------------------------------------------
# ['Low Price GR', 'Close Price GR', 'WAP GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 5001
# 4901.0
# 4901.0
# 4901.0
# Values in Same direction -----> -----> 421
# Values in Opposite direction <----- ----->  459
# Percentage of correct direction :  0.4784090909090909
# Features obtained from p-values less than 0.1 :
# -------------------------------------------------
# ['Low Price GR', 'Close Price GR', 'WAP GR', 'No. of Trades GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 8001
# 8101.0
# 8101.0
# 8101.0
# Values in Same direction -----> -----> 443
# Values in Opposite direction <----- ----->  437
# Percentage of correct direction :  0.5034090909090909
# Features obtained from p-values less than 0.2 :
# -------------------------------------------------
# ['Low Price GR', 'Close Price GR', 'WAP GR', 'No. of Trades GR', 'Beta GR', 'Net Profit GR', 'EPS GR']
# SVR Model fitted using columns obtained from feature importance using PValue :
# 2001
# 2701.0
# 2621.0
# 2616.0
# Values in Same direction -----> -----> 442
# Values in Opposite direction <----- ----->  438
# Percentage of correct direction :  0.5022727272727273
# *****************************************************************************************
# Features Importance using Forward Selection Method
# *****************************************************************************************
# Features obtained from Forward Selection method :
# --------------------------------------
# ['Low Price GR', 'No. of Trades GR']
# SVR Model fitted using columns obtained from feature importance using ForwardSelection :
# 2001
# 2901.0
# 2901.0
# 2901.0
# Values in Same direction -----> -----> 437
# Values in Opposite direction <----- ----->  443
# Percentage of correct direction :  0.4965909090909091
# *****************************************************************************************
# Features Importance using Backward Elimination Method
# *****************************************************************************************
# Features obtained from Backward Elimination method :
# --------------------------------------
# ['High Price GR', 'Low Price GR', 'Close Price GR', 'WAP GR', 'No. of Trades GR']
# SVR Model fitted using columns obtained from feature importance using BackwardElimination :
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-22-c202090767df> in get_results_from_each_set(data, name, final_df)
#       7     get_results_from_FI_PValue(df1, name, column, results)
#       8     get_results_from_FI_ForwardSelection(df1, name, column, results)
# ----> 9     get_results_from_FI_BackwardElimination(df1, name, column, results)
#      10     get_results_from_FI_FValues(df1, name, column, results)
#      11
#
# <ipython-input-21-461190b38e16> in get_results_from_FI_BackwardElimination(df1, name, column, results)
#      12         backward_features.append(column)
#      13         df_be = df1[backward_features]
# ---> 14         fit_SVR(df_be, column, method, '', name, results)
#      15     print("*****************************************************************************************")
#
# <ipython-input-16-3712f030edd2> in fit_SVR(df, column, method, value, name, results)
#       1 def fit_SVR(df, column, method, value, name, results):
#       2     print("SVR Model fitted using columns obtained from feature importance using " + method + " : ")
# ----> 3     c = Model(df, column)
#       4 #     print(c)
#       5     X = df.loc[:, df.columns != column]
#
# <ipython-input-8-20ebe1849ee4> in Model(dataset, y)
#      10 #         print("end    ------> " + str(end))
#      11 #         print("step   ------> " + str(step))
# ---> 12         best,step = bestParameters(start,end,step,X,Y)
#      13         for key in best:
#      14             if key == 'C':
#
# <ipython-input-9-ff8dcda70f63> in bestParameters(start, end, step, X, Y)
#       6     clf = GridSearchCV(svr, parameters, scoring = 'neg_mean_squared_error')
#       7     X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
# ----> 8     clf.fit(X_train,y_train)
#       9     best = clf.best_params_
#      10 #     print("best ", best)
#
# ~\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     839                 return results
#     840
# --> 841             self._run_search(evaluate_candidates)
#     842
#     843             # multimetric is determined here because in the case of a callable
#
# ~\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1286     def _run_search(self, evaluate_candidates):
#    1287         """Search all candidates in param_grid"""
# -> 1288         evaluate_candidates(ParameterGrid(self.param_grid))
#    1289
#    1290
#
# ~\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     793                               n_splits, n_candidates, n_candidates * n_splits))
#     794
# --> 795                 out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#     796                                                        X, y,
#     797                                                        train=train, test=test,
#
# ~\anaconda3\envs\tf\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1042                 self._iterating = self._original_iterator is not None
#    1043
# -> 1044             while self.dispatch_one_batch(iterator):
#    1045                 pass
#    1046
#
# ~\anaconda3\envs\tf\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     857                 return False
#     858             else:
# --> 859                 self._dispatch(tasks)
#     860                 return True
#     861
#
# ~\anaconda3\envs\tf\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     775         with self._lock:
#     776             job_idx = len(self._jobs)
# --> 777             job = self._backend.apply_async(batch, callback=cb)
#     778             # A job can complete so quickly than its callback is
#     779             # called before we get here, causing self._jobs to
#
# ~\anaconda3\envs\tf\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~\anaconda3\envs\tf\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~\anaconda3\envs\tf\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\envs\tf\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\envs\tf\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     220     def __call__(self, *args, **kwargs):
#     221         with config_context(**self.config):
# --> 222             return self.function(*args, **kwargs)
#
# ~\anaconda3\envs\tf\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     591             estimator.fit(X_train, **fit_params)
#     592         else:
# --> 593             estimator.fit(X_train, y_train, **fit_params)
#     594
#     595     except Exception as e:
#
# ~\anaconda3\envs\tf\lib\site-packages\sklearn\svm\_base.py in fit(self, X, y, sample_weight)
#     224
#     225         seed = rnd.randint(np.iinfo('i').max)
# --> 226         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     227         # see comment on the other call to np.iinfo in this file
#     228
#
# ~\anaconda3\envs\tf\lib\site-packages\sklearn\svm\_base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     275         self.support_, self.support_vectors_, self._n_support, \
#     276             self.dual_coef_, self.intercept_, self._probA, \
# --> 277             self._probB, self.fit_status_ = libsvm.fit(
#     278                 X, y,
#     279                 svm_type=solver_type, sample_weight=sample_weight,
#
# KeyboardInterrupt:

# %%
for name,table in tables.items():
    print(table)
# Out:
# +------------------------------------------------------------------------------------------------------------------------------------------+
# |                                                                   SVR                                                                    |
# +--------------------------------------------+----------------------+------------+-----------+----------+----------+-----------+-----------+
# |                  Company                   |        Method        | Percentage | r^2_score | Mean_SE  | Mean_AE  | Median_AE |    EVS    |
# +--------------------------------------------+----------------------+------------+-----------+----------+----------+-----------+-----------+
# | 500085-CHAMBAL FERTILISERS & CHEMICALS LTD |      PValue 0.2      |  0.469438  | -0.015414 | 0.000837 | 0.019307 |  0.013089 | -0.007934 |
# | 500085-CHAMBAL FERTILISERS & CHEMICALS LTD |  ForwardSelection    |  0.474328  |  0.013863 | 0.000813 | 0.019153 |  0.012848 |  0.020605 |
# | 500085-CHAMBAL FERTILISERS & CHEMICALS LTD | BackwardElimination  |  0.474328  |  0.013863 | 0.000813 | 0.019153 |  0.012848 |  0.020605 |
# | 500085-CHAMBAL FERTILISERS & CHEMICALS LTD |       FValue 1       |  0.49511   |  0.013831 | 0.000813 | 0.019136 |  0.012902 |  0.020241 |
# | 500085-CHAMBAL FERTILISERS & CHEMICALS LTD |      FValue 10       |  0.481663  |  0.01417  | 0.000813 | 0.019131 |  0.012867 |  0.019319 |
# |                500112-SBIN                 |   Coefficients 0.1   |  0.483296  |  0.01559  | 0.084251 | 0.027507 |  0.01267  |  0.016839 |
# |                500112-SBIN                 |     PValue 0.02      |  0.48441   |  0.013394 | 0.084439 | 0.027335 |  0.012641 |  0.014695 |
# |                500112-SBIN                 |     PValue 0.05      |  0.503341  | -0.000972 | 0.085668 | 0.028401 |  0.01257  |  6.6e-05  |
# |                500112-SBIN                 |      PValue 0.1      |  0.495546  |  0.00214  | 0.085402 | 0.02837  |  0.012638 |  0.003198 |
# |                500112-SBIN                 |      PValue 0.2      |  0.492205  |  0.00362  | 0.085275 | 0.028349 |  0.012679 |  0.004686 |
# |                500112-SBIN                 |  ForwardSelection    |  0.505568  |  0.011712 | 0.084583 | 0.028191 |  0.01271  |  0.012776 |
# |                500112-SBIN                 | BackwardElimination  |  0.503341  |  0.011409 | 0.084609 | 0.028204 |  0.012691 |  0.012475 |
# |                500112-SBIN                 |       FValue 1       |  0.483296  |  0.020142 | 0.083861 | 0.027315 |  0.01275  |  0.021445 |
# |                500112-SBIN                 |      FValue 10       |  0.48441   |  0.019309 | 0.083932 | 0.027316 |  0.012705 |  0.020618 |
# |                500112-SBIN                 |      FValue 100      |  0.504454  |  0.01261  | 0.084506 | 0.027363 |  0.012753 |  0.013941 |
# |                500112-SBIN                 |     FValue 1000      |  0.483296  |  0.012253 | 0.084536 | 0.027347 |  0.012618 |  0.013556 |
# |     500124-DR.REDDY'S LABORATORIES LTD     |   Coefficients 0.1   |  0.496599  |  0.001576 | 0.00034  | 0.013034 |  0.009226 |  0.001673 |
# |     500124-DR.REDDY'S LABORATORIES LTD     |     PValue 0.02      |  0.501134  |  0.001187 | 0.00034  | 0.013033 |  0.009197 |  0.001262 |
# |     500124-DR.REDDY'S LABORATORIES LTD     |     PValue 0.05      |  0.495465  |  0.001959 | 0.000339 | 0.013041 |  0.009255 |  0.001961 |
# |     500124-DR.REDDY'S LABORATORIES LTD     |      PValue 0.1      |  0.484127  | -0.004548 | 0.000342 | 0.013078 |  0.009206 | -0.004327 |
# |     500124-DR.REDDY'S LABORATORIES LTD     |      PValue 0.2      |  0.497732  | -0.014447 | 0.000345 | 0.013172 |  0.00923  | -0.014443 |
# |     500124-DR.REDDY'S LABORATORIES LTD     |  ForwardSelection    |  0.484127  |  0.000405 | 0.00034  | 0.013048 |  0.009247 |  0.000407 |
# |     500124-DR.REDDY'S LABORATORIES LTD     | BackwardElimination  |  0.484127  | -0.001444 | 0.000341 | 0.013056 |  0.009216 | -0.000982 |
# |     500124-DR.REDDY'S LABORATORIES LTD     |       FValue 1       |  0.496599  | -0.014279 | 0.000345 | 0.013174 |  0.009122 | -0.014279 |
# |            500180-HDFC Bank Ltd            |   Coefficients 0.1   |  0.538462  | -0.075448 | 0.021269 | 0.018745 |  0.007892 |  -0.0741  |
# |            500180-HDFC Bank Ltd            |     PValue 0.02      |  0.540691  | -0.152418 | 0.022791 | 0.018932 |  0.008068 | -0.151041 |
# |            500180-HDFC Bank Ltd            |     PValue 0.05      |  0.540691  | -0.152418 | 0.022791 | 0.018932 |  0.008068 | -0.151041 |
# |            500180-HDFC Bank Ltd            |      PValue 0.1      |  0.527313  |  -0.05323 | 0.020829 | 0.018696 |  0.007909 | -0.051953 |
# |            500180-HDFC Bank Ltd            |      PValue 0.2      |  0.528428  | -0.077789 | 0.021315 | 0.018754 |  0.008037 | -0.076469 |
# |            500180-HDFC Bank Ltd            |  ForwardSelection    |  0.507246  | -0.130768 | 0.022363 | 0.019002 |  0.008213 | -0.129299 |
# |            500180-HDFC Bank Ltd            | BackwardElimination  |  0.502787  | -0.097128 | 0.021697 | 0.019064 |  0.008419 | -0.095926 |
# |            500180-HDFC Bank Ltd            |       FValue 1       |  0.511706  | -0.090787 | 0.021572 | 0.018966 |  0.008265 | -0.089468 |
# |            500180-HDFC Bank Ltd            |      FValue 10       |  0.540691  | -0.152418 | 0.022791 | 0.018932 |  0.008068 | -0.151041 |
# |            500180-HDFC Bank Ltd            |      FValue 100      |  0.540691  | -0.152418 | 0.022791 | 0.018932 |  0.008068 | -0.151041 |
# |            500180-HDFC Bank Ltd            |     FValue 1000      |  0.540691  | -0.151677 | 0.022776 | 0.018921 |  0.007953 | -0.150252 |
# |          500182-HERO MOTOCORP LTD          |   Coefficients 0.1   |    0.52    |  0.002893 | 0.000425 | 0.014163 |  0.009763 |  0.004272 |
# |          500182-HERO MOTOCORP LTD          |     PValue 0.02      |  0.498889  | -0.004287 | 0.000428 | 0.014226 |  0.009934 | -0.002686 |
# |          500182-HERO MOTOCORP LTD          |     PValue 0.05      |  0.502222  | -0.003586 | 0.000427 | 0.014215 |  0.009965 | -0.001853 |
# |          500182-HERO MOTOCORP LTD          |      PValue 0.1      |  0.505556  | -0.004791 | 0.000428 | 0.014228 |  0.009964 | -0.002322 |
# |          500182-HERO MOTOCORP LTD          |      PValue 0.2      |  0.511111  | -0.005457 | 0.000428 | 0.014228 |  0.009941 | -0.003003 |
# |          500182-HERO MOTOCORP LTD          |  ForwardSelection    |  0.502222  |  0.000908 | 0.000425 | 0.014182 |  0.009791 |  0.002325 |
# |          500182-HERO MOTOCORP LTD          | BackwardElimination  |  0.502222  |  0.000908 | 0.000425 | 0.014182 |  0.009791 |  0.002325 |
# |          500182-HERO MOTOCORP LTD          |       FValue 1       |    0.5     | -0.000665 | 0.000426 | 0.014197 |  0.009678 |  0.001071 |
# |          500182-HERO MOTOCORP LTD          |      FValue 10       |  0.514444  |  0.002536 | 0.000425 | 0.014162 |  0.009865 |  0.004097 |
# |             500209-INFOSYS LTD             |   Coefficients 0.1   |  0.516129  |  0.016132 | 0.001977 | 0.015645 |  0.009821 |  0.016707 |
# |             500209-INFOSYS LTD             |     PValue 0.02      |  0.483871  | -0.023731 | 0.002057 | 0.015944 |  0.009753 | -0.023389 |
# |             500209-INFOSYS LTD             |     PValue 0.05      |  0.502781  | -0.021671 | 0.002053 | 0.015928 |  0.009699 | -0.021212 |
# |             500209-INFOSYS LTD             |      PValue 0.1      |  0.502781  | -0.021671 | 0.002053 | 0.015928 |  0.009699 | -0.021212 |
# |             500209-INFOSYS LTD             |      PValue 0.2      |  0.502781  | -0.021671 | 0.002053 | 0.015928 |  0.009699 | -0.021212 |
# |             500209-INFOSYS LTD             |  ForwardSelection    |  0.49277   | -0.021267 | 0.002052 | 0.015856 |  0.009975 | -0.021219 |
# |             500209-INFOSYS LTD             | BackwardElimination  |  0.502781  | -0.022414 | 0.002055 | 0.015925 |  0.009722 | -0.021997 |
# |             500209-INFOSYS LTD             |       FValue 1       |  0.518354  |  -0.00034 | 0.00201  | 0.015722 |  0.009883 | -0.000259 |
# |             500209-INFOSYS LTD             |      FValue 10       |  0.50723   |  0.017038 | 0.001975 | 0.015628 |  0.009738 |  0.017211 |
# |             500209-INFOSYS LTD             |      FValue 100      |  0.50723   |  0.017038 | 0.001975 | 0.015628 |  0.009738 |  0.017211 |
# |       500325-RELIANCE INDUSTRIES LTD       |   Coefficients 0.1   |  0.483871  | -0.025017 | 0.00204  | 0.016855 |  0.011456 | -0.023992 |
# |       500325-RELIANCE INDUSTRIES LTD       |     PValue 0.02      |  0.46941   | -0.029324 | 0.002048 | 0.016868 |  0.011576 |  -0.02861 |
# |       500325-RELIANCE INDUSTRIES LTD       |     PValue 0.05      |  0.480534  | -0.020106 | 0.00203  | 0.016859 |  0.011642 | -0.019275 |
# |       500325-RELIANCE INDUSTRIES LTD       |      PValue 0.1      |  0.491657  | -0.034561 | 0.002059 | 0.016994 |  0.011586 | -0.033974 |
# |       500325-RELIANCE INDUSTRIES LTD       |      PValue 0.2      |  0.491657  | -0.034561 | 0.002059 | 0.016994 |  0.011586 | -0.033974 |
# |       500325-RELIANCE INDUSTRIES LTD       |  ForwardSelection    |  0.458287  | -0.021629 | 0.002033 | 0.016859 |  0.011585 |  -0.0209  |
# |       500325-RELIANCE INDUSTRIES LTD       | BackwardElimination  |  0.497219  | -0.032069 | 0.002054 | 0.016869 |  0.011605 | -0.031321 |
# |       500325-RELIANCE INDUSTRIES LTD       |       FValue 1       |  0.46941   | -0.043143 | 0.002076 | 0.01692  |  0.011479 | -0.042262 |
# |       500325-RELIANCE INDUSTRIES LTD       |      FValue 10       |  0.474972  | -0.038465 | 0.002066 | 0.016891 |  0.011457 | -0.037461 |
# |       500325-RELIANCE INDUSTRIES LTD       |      FValue 100      |  0.46941   | -0.029324 | 0.002048 | 0.016868 |  0.011576 |  -0.02861 |
# |          500387-SHREE CEMENT LTD           |   Coefficients 0.1   |    0.5     |  -0.00037 | 0.000323 | 0.013619 |  0.011079 |  0.000432 |
# |          500387-SHREE CEMENT LTD           |     PValue 0.02      |  0.490119  | -0.001458 | 0.000323 | 0.013651 |  0.010727 |  0.000208 |
# |          500387-SHREE CEMENT LTD           |     PValue 0.05      |  0.490119  | -0.001458 | 0.000323 | 0.013651 |  0.010727 |  0.000208 |
# |          500387-SHREE CEMENT LTD           |      PValue 0.1      |  0.490119  | -0.001458 | 0.000323 | 0.013651 |  0.010727 |  0.000208 |
# |          500387-SHREE CEMENT LTD           |      PValue 0.2      |  0.48419   | -0.010156 | 0.000326 | 0.013747 |  0.011075 | -0.009425 |
# |          500387-SHREE CEMENT LTD           | BackwardElimination  |  0.490119  | -0.001458 | 0.000323 | 0.013651 |  0.010727 |  0.000208 |
# |          500387-SHREE CEMENT LTD           |       FValue 1       |  0.496047  | -0.001207 | 0.000323 | 0.013676 |  0.01094  |  -0.00032 |
# |             500680-PFIZER LTD              |   Coefficients 0.1   |  0.495455  |  0.004281 | 0.00043  | 0.012291 |  0.008223 |  0.004582 |
# |             500680-PFIZER LTD              |     PValue 0.02      |  0.478409  |  0.003382 | 0.00043  | 0.012303 |  0.008269 |  0.003875 |
# |             500680-PFIZER LTD              |     PValue 0.05      |  0.478409  |  0.003382 | 0.00043  | 0.012303 |  0.008269 |  0.003875 |
# |             500680-PFIZER LTD              |      PValue 0.1      |  0.503409  | -0.065989 | 0.00046  | 0.012453 |  0.008471 |  -0.06502 |
# |             500680-PFIZER LTD              |      PValue 0.2      |  0.502273  | -0.265805 | 0.000547 | 0.01264  |  0.008514 | -0.264164 |
# |             500680-PFIZER LTD              |  ForwardSelection    |  0.496591  | -0.094275 | 0.000473 | 0.012484 |  0.008527 | -0.093172 |
# +--------------------------------------------+----------------------+------------+-----------+----------+----------+-----------+-----------+

# %%
final_df.tail(10)
# Out:
#                                         Company              Model  \
# 126            542602-EMBASSY OFFICE PARKS REIT  Linear Regression
# 127            542602-EMBASSY OFFICE PARKS REIT   Ridge Regression
# 128  500085-CHAMBAL FERTILISERS & CHEMICALS LTD                SVR
# 129                                 500112-SBIN                SVR
# 130          500124-DR.REDDY'S LABORATORIES LTD                SVR
# 131                        500180-HDFC Bank Ltd                SVR
# 132                    500182-HERO MOTOCORP LTD                SVR
# 133                          500209-INFOSYS LTD                SVR
# 134              500325-RELIANCE INDUSTRIES LTD                SVR
# 135                     500387-SHREE CEMENT LTD                SVR
#
#                           Method  Percentage
# 126      LinearFICoefficients0.1    0.538462
# 127       RidgeFICoefficients0.1    0.538462
# 128              SVR_FI_FValue_1    0.495110
# 129     SVR_FI_ForwardSelection_    0.505568
# 130           SVR_FI_PValue_0.02    0.501134
# 131           SVR_FI_FValue_1000    0.540691
# 132      SVR_FI_Coefficients_0.1    0.520000
# 133              SVR_FI_FValue_1    0.518354
# 134  SVR_FI_BackwardElimination_    0.497219
# 135      SVR_FI_Coefficients_0.1    0.500000
